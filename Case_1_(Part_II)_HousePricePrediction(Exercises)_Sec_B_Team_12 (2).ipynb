# %% [markdown]
# # House price prediction for Denver Dataset
#
# In this case (Part II), there are two main tasks:
#
# - First, you will need to split the train data into train and validate data and tune the model hyperparameters to choose the best model. Submit the predicted prices for test data to Kaggle to compete for Prof. X's Prize!
#
# - Then you will examine the profit of the iBuyer business model based on the predicted price on the valid data.

# %% [markdown]
# You need to submit a report in pdf format containing the following material on canvas site:
#
# 1.   A plot of the training errors and validation errors over epochs for a base multilayer perceptron model with 2 hidden layers of sizes 256 and 128.
#
# 2.   A plot of the training errors and validation errors over epochs for a  multilayer perceptron model with 4 hidden layers of sizes 512, 256, 128, 64.
#
# 3.  A plot of the training errors and validation errors over epochs for a  multilayer perceptron model with 4 hidden layers of sizes 512, 256, 128, 64
# and norm regularization.
#
# 4. A plot of the training errors and validation errors over epochs for a  multilayer perceptron model with 4 hidden layers of sizes 512, 256, 128, 64
# and norm regularization and dropout layers.
#
# 5. A table listing all the model hyperparameters that you have tried with the corresponding validation errors that you found.
#
# 6. Your profit analysis of the the iBuyer business model based on the predicted price on the valid data and answers to the four questions therein.
#
#
# You also need to submit on canvas site:
#
# - The complete Juyputer notebook containing all your Pytorch code with explanations, along with a Markdown text explaining different parts if needed.
# -  A checkpoint.pth file containing all the necessary information to retrieve your best model and predictions.

# %% [markdown]
# ---
# ## Data Loading and Visualize Data

# %% [markdown]
# The train data and test data are available on Kaggle website.
# You can first download them, then upload them to the google colab, and then read the data using pandas.

# %%
import pandas as pd  # Importing pandas, which is a library for data manipulation and analysis
#TODO: Read the datasets
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
# Display the train dataframe
print(train_df.shape)
print(train_df.columns)
# Out:
# (11581, 17)
# Index(['ID', 'NBHD', 'PROP_CLASS', 'LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA',
#        'LAND_SQFT', 'GRD_AREA', 'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B',
#        'HLF_B', 'STORY', 'STYLE_CN', 'UNITS', 'SALE_PRICE'],
#       dtype='object')

# %%
# Display the test dataframe
print(test_df.shape)
print(test_df.columns)
# Out:
# (4964, 16)
# Index(['ID', 'NBHD', 'PROP_CLASS', 'LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA',
#        'LAND_SQFT', 'GRD_AREA', 'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B',
#        'HLF_B', 'STORY', 'STYLE_CN', 'UNITS'],
#       dtype='object')

# %% [markdown]
# As you can see, we have 11581 training samples and 4964 test samples, each with 16 features. The training samples contain the sale_prices, which are the labels. The test samples do not contain the sale_prices, which we will predict by building a MLP model.

# %% [markdown]
# ### Visualization of SALE PRICES
#
# Let's take a closer look at the sale prices in the train data.

# %%
import seaborn as sns
import matplotlib.pyplot as plt  # Importing matplotlib's pyplot, it provides a MATLAB-like interface for making plots and charts

# Set the style
sns.set(style="whitegrid")

# Create a histogram
plt.figure(figsize=(10, 6))
sns.histplot(train_df['SALE_PRICE'], bins=50, color='blue')
plt.title('Histogram of Sale Prices (Train Data)')
plt.xlabel('Sale Price')
plt.ylabel('Number of Properties')
plt.show()

# %% [markdown]
# Check the minimum and maximum sale_price in train data.

# %%
print(train_df['SALE_PRICE'].min())
print(train_df['SALE_PRICE'].max())
print(train_df['SALE_PRICE'].median())
# Out:
# 51000
# 1995000
# 431000.0

# %% [markdown]
# We see that the sale_price has a wide range from 50K to 2 million, with the median price 431K.

# %% [markdown]
# ### Visualization of Correlation
#
# We can also compute and visualize the correlation matrix.

# %%
# Compute the correlation matrix:
correlation_matrix = train_df.corr(numeric_only=True)

# 1. Increase the figure size for clarity
plt.figure(figsize=(8, 8))

# 2. Use a heatmap with annotations, a color map, and specific formatting for the annotations
ax = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={'size': 8})

# 3. Rotate the x-axis labels for better visibility
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Rotate the y-axis labels
plt.setp(ax.get_yticklabels(), rotation=0)

# 4. Title and display
plt.title('Correlation Heatmap')
plt.tight_layout()  # This can help if any labels are still being cut off
plt.show()

# 5. Optionally save the figure with high resolution
# plt.savefig("heatmap.png", dpi=300)

# %% [markdown]
# We can see that the Sale_Price has high correlation with Living_SQFT and number of Full Bathrooms.

# %% [markdown]
# ### Distribution of houses over different NBHD

# %%
# Compute the number of houses per neighborhood
House_by_NBHD = train_df['NBHD'].value_counts()
print(House_by_NBHD )
# Out:
# NBHD
# CENTRAL PARK                    1049
# GATEWAY / GREEN VALLEY RANCH     937
# UNION STATION                    369
# HAMPDEN                          346
# WINDSOR                          316
#                                 ...
# VALVERDE                          22
# GLOBEVILLE                        20
# SUN VALLEY                         8
# CORY - MERRILL                     4
# AURARIA                            1
# Name: count, Length: 75, dtype: int64

# %%
# Filtering ZIP codes that appear more than once
filtered_House_by_NBHD = House_by_NBHD[House_by_NBHD > 200]
filtered_House_by_NBHD.plot(kind='bar', figsize=(10,6))
plt.title('Distribution of Houses by NBHD')
plt.ylabel('Number of Houses')
plt.xlabel('NBHD')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability, if necessary
plt.tight_layout()  # Ensure everything fits without overlapping
plt.show()

# %% [markdown]
# ---
# ## Data Preparation
#
# The first step when building a neural network model is getting your data into the proper form to feed into the network.
#
# - Train labels: We need to extract the sale prices from the train data as train labels. Since the house prices can take very large values, to make training fast it is helpful to define the train labels as the sale prices divided by a normalization factor.
#
# - **Handing non-numeric features**: Some of the house features are non-numeric. We will learn about how to process categorical data in the upcoming lectures. For now, you can  remove those non-numeric features and only train over the numeric features.
#
# - **Feature standardization**: When predicting house prices, you started from features that took a variety of ranges—some features had small floating-point values, and others had fairly large integer values. The model might be able to automatically adapt to such heterogeneous data, but it would definitely make learning more difficult. A widespread best practice for dealing with such data is to do feature-wise normalization: for each feature in the input data (a column in the input dataframe), we subtract the mean of the feature and divide by the standard deviation, so that the feature is centered around 0 and has
# a unit standard deviation. Note that here we combine the feature vectors in the train and test data. In this way, the train and test data go through the same normalization.
#
# - **Handling missing values**: There may exist some entries with missing values. After the feature standardization, we can impute the missing values with zeros.

# %% [markdown]
# We see that the sale_price in train data has a wide range from 50K to 2 million, with the median price 431K. We can divide the sale_price by 100K, so the normalized sale_price is between 0.5 and 20 in training data. Remember, when we output the predicted price for the test data, we need to multiply back the normalization factor.

# %%
#TODO: define labels for train data
normalization_factor=100000
train_labels = train_df['SALE_PRICE']/normalization_factor
train_df.drop('SALE_PRICE', axis=1, inplace=True) # drop the sale_prices in features.

# %% [markdown]
# The inplace parameter, when set to True , allows you to drop the rows or columns without returning a new DataFrame. The issue arises when the drop function reorders the DataFrame, which can be problematic when the order of your data matters

# %% [markdown]
# Note that both the training samples and test samples contain an ID column, which is not informative for predicting the house price. Thus we will drop the ID column.

# %%
train_ID=train_df['ID']
test_ID=test_df['ID']
train_df.drop('ID', axis=1, inplace=True)
test_df.drop('ID', axis=1, inplace=True)

# %%
# Then we combine the feature vectors in the train data and test data
features=pd.concat(objs=[train_df,test_df],axis=0)

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16545 entries, 0 to 4963
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NBHD         16545 non-null  object
#  1   PROP_CLASS   16545 non-null  object
#  2   LIVING_SQFT  16545 non-null  int64
#  3   FBSMT_SQFT   16545 non-null  int64
#  4   BSMT_AREA    16545 non-null  int64
#  5   LAND_SQFT    16545 non-null  int64
#  6   GRD_AREA     16545 non-null  int64
#  7   BLDG_AGE     16545 non-null  int64
#  8   RM_AGE       8705 non-null   float64
#  9   BED_RMS      16545 non-null  float64
#  10  FULL_B       16545 non-null  float64
#  11  HLF_B        16545 non-null  int64
#  12  STORY        16545 non-null  float64
#  13  STYLE_CN     16545 non-null  object
#  14  UNITS        16545 non-null  float64
# dtypes: float64(5), int64(7), object(3)
# memory usage: 2.0+ MB

# %% [markdown]
# We see that there are three non-numeric features, namely `NBHD`, `PROP_CLASS`, and `STYLE_CN`. We will apply one-hot encoding to those non-numeric features in our model; you could also simply drop these non-numeric features.

# %%
numeric_features = features.dtypes[features.dtypes != 'object'].index
non_numeric_features = features.dtypes[features.dtypes == 'object'].index
numeric_features, non_numeric_features
# Out:
# (Index(['LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA', 'LAND_SQFT', 'GRD_AREA',
#         'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B', 'HLF_B', 'STORY', 'UNITS'],
#        dtype='object'),
#  Index(['NBHD', 'PROP_CLASS', 'STYLE_CN'], dtype='object'))

# %%
# If you want to drop the non-numeric features, you just set drop_non_numeric_features= True.
drop_non_numeric_features= False

if drop_non_numeric_features:
    features= features.drop(non_numeric_features, axis=1)
else:
    # One-hot encode categorical features
    features = pd.get_dummies(features, columns=non_numeric_features, dummy_na=True)

# Check for non-numeric columns
non_numeric_cols = features.select_dtypes(include=['object']).columns
if not non_numeric_cols.empty:
    raise ValueError(f"DataFrame contains non-numeric columns: {non_numeric_cols.tolist()}")

# %%
# Standardize numeric features
features[numeric_features] = features[numeric_features].apply(lambda x: (x - x.mean()) / (x.std()))

# %%
# recheck the mean and std after standardization
features[numeric_features].mean(), features[numeric_features].std()
# Out:
# (LIVING_SQFT   -7.343778e-17
#  FBSMT_SQFT     2.362034e-18
#  BSMT_AREA      6.543907e-17
#  LAND_SQFT      3.929565e-17
#  GRD_AREA       1.868154e-17
#  BLDG_AGE      -2.018465e-17
#  RM_AGE         1.938586e-17
#  BED_RMS        2.304594e-16
#  FULL_B         1.489155e-16
#  HLF_B         -1.857418e-17
#  STORY          1.803735e-17
#  UNITS          4.975302e-16
#  dtype: float64,
#  LIVING_SQFT    1.0
#  FBSMT_SQFT     1.0
#  BSMT_AREA      1.0
#  LAND_SQFT      1.0
#  GRD_AREA       1.0
#  BLDG_AGE       1.0
#  RM_AGE         1.0
#  BED_RMS        1.0
#  FULL_B         1.0
#  HLF_B          1.0
#  STORY          1.0
#  UNITS          1.0
#  dtype: float64)

# %% [markdown]
# We see that after standardization, the features for the train data have mean 0 and standard deviation 1.

# %%
# After the feature standardization, we can impute the missing values with zeros.
features[numeric_features] = features[numeric_features].fillna(0)

# %% [markdown]
# Double check the features after data processing.

# %%
features.info()
print(features.columns)
features.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16545 entries, 0 to 4963
# Columns: 105 entries, LIVING_SQFT to STYLE_CN_nan
# dtypes: bool(93), float64(12)
# memory usage: 3.1 MB
# Index(['LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA', 'LAND_SQFT', 'GRD_AREA',
#        'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B', 'HLF_B',
#        ...
#        'STYLE_CN_3 STORY', 'STYLE_CN_BI-LEVEL', 'STYLE_CN_CONVERSION',
#        'STYLE_CN_END UNIT', 'STYLE_CN_MIDDLE UNIT', 'STYLE_CN_RANCH',
#        'STYLE_CN_SPLIT LEVEL', 'STYLE_CN_TRI-LEVEL', 'STYLE_CN_TRI-LEVEL W/B',
#        'STYLE_CN_nan'],
#       dtype='object', length=105)
#    LIVING_SQFT  FBSMT_SQFT  BSMT_AREA  LAND_SQFT  GRD_AREA  BLDG_AGE  \
# 0    -0.740106   -0.692044  -0.823130  -1.139796 -0.167508  0.356733
# 1     1.242076    1.243805   0.889598  -0.235148 -0.167508 -1.055565
# 2    -0.640294    0.936220   0.634857   1.436642 -0.167508  0.539809
# 3    -0.813208   -0.692044  -0.823130   0.626077 -0.167508  0.801346
# 4     0.385942   -0.692044  -0.823130  -0.514503 -0.167508 -1.186333
#
#      RM_AGE   BED_RMS    FULL_B     HLF_B  ...  STYLE_CN_3 STORY  \
# 0 -0.257022 -0.498851 -0.062554 -0.775340  ...             False
# 1  0.000000  0.611982  2.217079  1.076812  ...             False
# 2 -0.005490  0.611982 -0.062554 -0.775340  ...             False
# 3  1.126401 -0.498851 -1.202370 -0.775340  ...             False
# 4  0.000000  0.611982 -0.062554  1.076812  ...             False
#
#    STYLE_CN_BI-LEVEL  STYLE_CN_CONVERSION  STYLE_CN_END UNIT  \
# 0              False                False               True
# 1              False                False               True
# 2              False                False              False
# 3              False                False              False
# 4              False                False              False
#
#    STYLE_CN_MIDDLE UNIT  STYLE_CN_RANCH  STYLE_CN_SPLIT LEVEL  \
# 0                 False           False                 False
# 1                 False           False                 False
# 2                 False           False                 False
# 3                 False           False                 False
# 4                  True           False                 False
#
#    STYLE_CN_TRI-LEVEL  STYLE_CN_TRI-LEVEL W/B  STYLE_CN_nan
# 0               False                   False         False
# 1               False                   False         False
# 2               False                   False         False
# 3               False                   False         False
# 4               False                   False         False
#
# [5 rows x 105 columns]

# %% [markdown]
# Note that after the one-hot encoding of the non-numeric features, now we have 105-dimensional feature.

# %%
# check whether there is any missing entry
print(features.isnull().sum())
# Out:
# LIVING_SQFT               0
# FBSMT_SQFT                0
# BSMT_AREA                 0
# LAND_SQFT                 0
# GRD_AREA                  0
#                          ..
# STYLE_CN_RANCH            0
# STYLE_CN_SPLIT LEVEL      0
# STYLE_CN_TRI-LEVEL        0
# STYLE_CN_TRI-LEVEL W/B    0
# STYLE_CN_nan              0
# Length: 105, dtype: int64

# %%
# we extract out the train and test features
train_features = features.iloc[:len(train_labels)]
test_features = features.iloc[len(train_labels):]
train_features.shape, test_features.shape
# Out:
# ((11581, 105), (4964, 105))

# %%
import torch
import numpy as np

# Convert training features and labels to PyTorch tensors
train_features = torch.tensor(train_features.values.astype(np.float32), dtype=torch.float32)
test_features = torch.tensor(test_features.values.astype(np.float32), dtype=torch.float32)
train_labels = torch.tensor(train_labels.values.reshape(-1, 1).astype(np.float32), dtype=torch.float32)

# %%
train_labels
# Out:
# tensor([[ 2.8500],
#         [12.3000],
#         [ 4.2000],
#         ...,
#         [ 6.0200],
#         [ 3.8370],
#         [ 5.5000]])

# %%
train_labels.shape
# Out:
# torch.Size([11581, 1])

# %%
train_features.shape
# Out:
# torch.Size([11581, 105])

# %% [markdown]
# ---
# ## Training and Validation
#
# To prevent overfitting, we'll split it our training data into training and validation. We will use validation set to select the appropriate model.
# One way is to use the [`train_test_split` function](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html). You're more than welcome to use your own way.

# %%
#TODO: filling in the missing code to split train data into train and validation
from sklearn.model_selection import train_test_split  # Importing train_test_split function from sklearn for splitting data into training set and validation set
# Splitting the training data: 20% is validation data

indices = np.arange(len(train_labels))
train_indices, valid_indices, train_features, valid_features, train_labels, valid_labels = train_test_split(
    indices, train_features, train_labels, test_size=0.2, random_state=42
)

# %%
print(train_features.shape)
print(valid_features.shape)
# Out:
# torch.Size([9264, 105])
# torch.Size([2317, 105])

# %% [markdown]
# ---
# ## DataLoaders and Batching
#
# After creating training, test, and validation data, we can create DataLoaders for this data by following two steps:
# 1. Create a known format for accessing our data, using [TensorDataset](https://pytorch.org/docs/stable/data.html#torch.utils.data.TensorDataset) which takes in an input set of data and a target set of data with the same first dimension, and creates a dataset.
# 2. Create DataLoaders and batch our training, validation, and test Tensor datasets. Note that we will shuffle the train data, so the model will not learn a particular order. For valid and test data, we do not shuffle.

# %%
from torch.utils.data import TensorDataset, DataLoader
train_data = TensorDataset(train_features, train_labels)
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
#TODO: create dataloader for validation data
valid_data = TensorDataset(valid_features, valid_labels)
valid_loader = DataLoader(valid_data, batch_size=32, shuffle=False)

# %%
test_data = TensorDataset(test_features)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# %% [markdown]
# Let's take a batch to have a sanity check

# %%
# obtain one batch of training data
dataiter = iter(train_loader)
features, labels = next(dataiter)

print('Sample input size: ', features.size()) # batch_size, seq_length
print('Sample input: \n', features)
print()
print('Sample label size: ', labels.size()) # batch_size
print('Sample label: \n', labels)
# Out:
# Sample input size:  torch.Size([32, 105])
# Sample input:
#  tensor([[-0.5264,  1.1664,  1.1281,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6179,  1.2266,  0.8733,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6446,  1.1922,  2.6330,  ...,  0.0000,  0.0000,  0.0000],
#         ...,
#         [-0.8427, -0.6920, -0.8231,  ...,  0.0000,  0.0000,  0.0000],
#         [-0.0485, -0.0468, -0.0788,  ...,  0.0000,  0.0000,  0.0000],
#         [-0.7134,  1.3449,  0.8878,  ...,  0.0000,  0.0000,  0.0000]])
#
# Sample label size:  torch.Size([32, 1])
# Sample label:
#  tensor([[4.4000],
#         [7.7900],
#         [5.1500],
#         [2.9800],
#         [3.2290],
#         [5.7250],
#         [1.9800],
#         [4.8750],
#         [8.0350],
#         [7.3990],
#         [5.4111],
#         [1.9900],
#         [8.5000],
#         [3.6625],
#         [4.1000],
#         [5.6750],
#         [2.9500],
#         [5.4200],
#         [5.8400],
#         [4.5500],
#         [2.9900],
#         [4.8900],
#         [4.5900],
#         [7.0000],
#         [4.2000],
#         [3.7000],
#         [2.5200],
#         [3.2500],
#         [2.4500],
#         [2.1800],
#         [3.2000],
#         [4.2000]])

# %% [markdown]
# ---
# ## Linear Regression as Benchmark
#
# Let us build a linear regression model as a benchmark. Note that the linear regression model can be viewed as a special instance of multi-layer perception with no hidden layer and a single output neuron.

# %%
# Build a linear regression model network
import torch.nn as nn
lin_net = nn.Linear(train_features.shape[1], 1)

# %% [markdown]
# Let's print out the model achitecture.

# %%
lin_net
# Out:
# Linear(in_features=105, out_features=1, bias=True)

# %% [markdown]
# Let's take a batch and see the output

# %%
features, labels = next(dataiter)
output=lin_net(features)
output.shape,labels.shape
# Out:
# (torch.Size([32, 1]), torch.Size([32, 1]))

# %%
valid_labels.shape
# Out:
# torch.Size([2317, 1])

# %% [markdown]
# ---
# ## Train the model

# %% [markdown]
# First, we will use GPU training if it is availabe.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
lin_net = lin_net.to(device)

# %% [markdown]
# Second, let us specify the loss function.

# %%
#Since both the output and the label are real valued, we will use the standard mean-squared loss.
criterion = nn.MSELoss()

# %% [markdown]
# Third, while we are using the mean-squared loss for training loss, we will use
# a different metric to measure the predictive performance.
#
# Note that with house prices, as with stock prices, we care about relative quantities more than absolute quantities. Thus we tend to care more about the relative error than about the absolute error. For instance, if our prediction is off by \\$100,000 when estimating the sale price of a house which is \\$125,000, then we are probably doing a horrible job. On the other hand, if we err by this amount for a house with sale price \\$2 million, this might represent a pretty  accurate prediction.
#
# To address this issue, we will use the median error rate (MER) used by [Zestimate](https://www.zillow.com/z/zestimate/) to measure the predictive performance. The error rate is defined as
# $$
# \text{Error Rate} = \left| \frac{\text{Predicted Price}-\text{Actual Price}}{\text{Actual Price}} \right|
# $$
# The median error rate is defined as the median of error rates for all properties.

# %% [markdown]
# We are now ready to train the network. Let’s try training the model a bit longer: 200 epochs. To keep a record of how well the model does at each epoch, we will save the per-epoch training error and validation error in the training loop.

# %%
#Function to calculate MER
def calculate_mer(predictions, targets):
    errors = np.abs((predictions - targets) / targets)
    mer = np.median(errors)
    return mer

# %%
# Training loop
lin_net.to(device)
optimizer = torch.optim.Adam(lin_net.parameters(), lr=0.001)
epochs = 20
train_losses = []
valid_losses = []
train_mers = []
valid_mers = []

for e in range(epochs):
    running_train_loss = 0
    all_train_preds = []  # List to store predictions for the epoch
    all_train_labels = []  # List to store targets for the epoch

    # Training loop for one epoch
    lin_net.train()  # Set the model to training mode
    for train_features, train_labels in train_loader:
        train_features = train_features.to(device)
        train_labels = train_labels.to(device)

        # Forward pass
        output = lin_net(train_features)
        loss = criterion(output, train_labels)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Accumulate training loss
        running_train_loss += loss.item()

        # Collect predictions and labels for MER calculation
        all_train_preds.extend(output.cpu().detach().numpy().flatten())
        all_train_labels.extend(train_labels.cpu().numpy().flatten())

    # Calculate average training loss for the epoch
    epoch_train_loss = running_train_loss / len(train_loader)
    train_losses.append(epoch_train_loss)

    # Calculate training MER
    train_mer = calculate_mer(np.array(all_train_preds), np.array(all_train_labels))
    train_mers.append(train_mer)

    # Validation loop for one epoch
    lin_net.eval()  # Set the model to evaluation mode
    running_valid_loss = 0.0
    all_valid_preds = []
    all_valid_labels = []

    with torch.no_grad():  # Disable gradient calculation during validation
        for valid_features, valid_labels in valid_loader:
            valid_features = valid_features.to(device)
            valid_labels = valid_labels.to(device)

            # Forward pass
            outputs = lin_net(valid_features)
            loss = criterion(outputs, valid_labels)
            running_valid_loss += loss.item()

            # Collect predictions and labels for MER calculation
            all_valid_preds.extend(outputs.cpu().numpy().flatten())
            all_valid_labels.extend(valid_labels.cpu().numpy().flatten())

    # Calculate average validation loss for the epoch
    epoch_valid_loss = running_valid_loss / len(valid_loader)
    valid_losses.append(epoch_valid_loss)

    # Calculate validation MER
    valid_mer = calculate_mer(np.array(all_valid_preds), np.array(all_valid_labels))
    valid_mers.append(valid_mer)

    print(f'Epoch [{e + 1}/{epochs}], Train Loss: {epoch_train_loss:.4f}, Train MER: {train_mer:.4f}, Valid Loss: {epoch_valid_loss:.4f}, Valid MER: {valid_mer:.4f}')
# Out:
# Epoch [1/20], Train Loss: 27.4434, Train MER: 0.9417, Valid Loss: 22.6016, Valid MER: 0.8324
# Epoch [2/20], Train Loss: 18.6040, Train MER: 0.7526, Valid Loss: 15.5301, Valid MER: 0.6630
# Epoch [3/20], Train Loss: 12.9371, Train MER: 0.5916, Valid Loss: 10.9730, Valid MER: 0.5186
# Epoch [4/20], Train Loss: 9.2333, Train MER: 0.4502, Valid Loss: 7.9978, Valid MER: 0.3960
# Epoch [5/20], Train Loss: 6.8595, Train MER: 0.3427, Valid Loss: 6.1406, Valid MER: 0.3072
# Epoch [6/20], Train Loss: 5.3987, Train MER: 0.2728, Valid Loss: 5.0331, Valid MER: 0.2546
# Epoch [7/20], Train Loss: 4.5163, Train MER: 0.2345, Valid Loss: 4.3036, Valid MER: 0.2281
# Epoch [8/20], Train Loss: 3.9796, Train MER: 0.2134, Valid Loss: 3.8777, Valid MER: 0.2046
# Epoch [9/20], Train Loss: 3.6435, Train MER: 0.1998, Valid Loss: 3.5988, Valid MER: 0.1923
# Epoch [10/20], Train Loss: 3.4170, Train MER: 0.1876, Valid Loss: 3.4448, Valid MER: 0.1850
# Epoch [11/20], Train Loss: 3.2394, Train MER: 0.1800, Valid Loss: 3.2157, Valid MER: 0.1744
# Epoch [12/20], Train Loss: 3.0961, Train MER: 0.1724, Valid Loss: 3.0695, Valid MER: 0.1672
# Epoch [13/20], Train Loss: 2.9836, Train MER: 0.1659, Valid Loss: 2.9622, Valid MER: 0.1605
# Epoch [14/20], Train Loss: 2.8870, Train MER: 0.1589, Valid Loss: 2.9137, Valid MER: 0.1561
# Epoch [15/20], Train Loss: 2.8045, Train MER: 0.1542, Valid Loss: 2.8572, Valid MER: 0.1518
# Epoch [16/20], Train Loss: 2.7426, Train MER: 0.1494, Valid Loss: 2.7299, Valid MER: 0.1479
# Epoch [17/20], Train Loss: 2.6857, Train MER: 0.1469, Valid Loss: 2.6876, Valid MER: 0.1454
# Epoch [18/20], Train Loss: 2.6374, Train MER: 0.1430, Valid Loss: 2.6764, Valid MER: 0.1443
# Epoch [19/20], Train Loss: 2.5895, Train MER: 0.1417, Valid Loss: 2.6230, Valid MER: 0.1423
# Epoch [20/20], Train Loss: 2.5491, Train MER: 0.1384, Valid Loss: 2.5803, Valid MER: 0.1405

# %% [markdown]
# Define a function to plot errors.

# %%
#TODO: Write code to plot the training and vadliation errors (MER) over epochs

import matplotlib.pyplot as plt

# Plotting the validation MER over epochs
plt.plot(train_mers, label='Training MER')
plt.plot(valid_mers, label='Validation MER')
plt.xlabel('Epoch')
plt.ylabel('Median Error Rate (MER)')
plt.title('Training and Validation Error (MER) over Epochs')
plt.legend()
plt.show()

# Print the last value of validation MER
print(valid_mers[-1])
# Out:
# 0.1404748

# %% [markdown]
# ---
# ## Build the Multi-layer Perceptron Base Model

# %% [markdown]
# In the following, we build a multi-layer perception model with 2 hidden layers of sizes 256 and 128, respectively and ReLu activations.

# %%
# Build a feed-forward network
import torch.nn as nn
model = nn.Sequential(nn.Linear(train_features.shape[1], 256),
                      nn.ReLU(),
                      nn.Linear(256, 128),
                      nn.ReLU(),
                      nn.Linear(128,1))

# %% [markdown]
# Let's print out the model achitecture.

# %%
model
# Out:
# Sequential(
#   (0): Linear(in_features=105, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=128, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
model = model.to(device)

# %%
#TODO: write code to train the MLP network and save training and validation error.
# Training loop
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
epochs = 50
train_losses = []
valid_losses = []
train_mers = []
valid_mers = []

for e in range(epochs):
    running_train_loss = 0
    all_train_preds = []  # List to store predictions for the epoch
    all_train_labels = []  # List to store targets for the epoch

    # Training loop for one epoch
    model.train()  # Set the model to training mode
    for train_features, train_labels in train_loader:
        train_features = train_features.to(device)
        train_labels = train_labels.to(device)

        # Forward pass
        output = model(train_features)
        loss = criterion(output, train_labels)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Accumulate training loss
        running_train_loss += loss.item()

        # Collect predictions and labels for MER calculation
        all_train_preds.extend(output.cpu().detach().numpy().flatten())
        all_train_labels.extend(train_labels.cpu().numpy().flatten())

    # Calculate average training loss for the epoch
    epoch_train_loss = running_train_loss / len(train_loader)
    train_losses.append(epoch_train_loss)

    # Calculate training MER
    train_mer = calculate_mer(np.array(all_train_preds), np.array(all_train_labels))
    train_mers.append(train_mer)

    # Validation loop for one epoch
    model.eval()  # Set the model to evaluation mode
    running_valid_loss = 0.0
    all_valid_preds = []
    all_valid_labels = []

    with torch.no_grad():  # Disable gradient calculation during validation
        for valid_features, valid_labels in valid_loader:
            valid_features = valid_features.to(device)
            valid_labels = valid_labels.to(device)

            # Forward pass
            outputs = model(valid_features)
            loss = criterion(outputs, valid_labels)
            running_valid_loss += loss.item()

            # Collect predictions and labels for MER calculation
            all_valid_preds.extend(outputs.cpu().numpy().flatten())
            all_valid_labels.extend(valid_labels.cpu().numpy().flatten())

    # Calculate average validation loss for the epoch
    epoch_valid_loss = running_valid_loss / len(valid_loader)
    valid_losses.append(epoch_valid_loss)

    # Calculate validation MER
    valid_mer = calculate_mer(np.array(all_valid_preds), np.array(all_valid_labels))
    valid_mers.append(valid_mer)

    print(f'Epoch [{e + 1}/{epochs}], Train Loss: {epoch_train_loss:.4f}, Train MER: {train_mer:.4f}, Valid Loss: {epoch_valid_loss:.4f}, Valid MER: {valid_mer:.4f}')
# Out:
# Epoch [1/50], Train Loss: 4.6840, Train MER: 0.1812, Valid Loss: 2.4195, Valid MER: 0.1309
# Epoch [2/50], Train Loss: 2.2429, Train MER: 0.1305, Valid Loss: 2.2376, Valid MER: 0.1304
# Epoch [3/50], Train Loss: 2.0472, Train MER: 0.1198, Valid Loss: 2.1036, Valid MER: 0.1206
# Epoch [4/50], Train Loss: 1.9124, Train MER: 0.1127, Valid Loss: 2.0439, Valid MER: 0.1117
# Epoch [5/50], Train Loss: 1.8486, Train MER: 0.1120, Valid Loss: 2.1729, Valid MER: 0.1239
# Epoch [6/50], Train Loss: 1.7856, Train MER: 0.1118, Valid Loss: 1.9433, Valid MER: 0.1097
# Epoch [7/50], Train Loss: 1.7328, Train MER: 0.1088, Valid Loss: 1.9443, Valid MER: 0.1136
# Epoch [8/50], Train Loss: 1.6665, Train MER: 0.1105, Valid Loss: 2.0917, Valid MER: 0.1211
# Epoch [9/50], Train Loss: 1.6159, Train MER: 0.1044, Valid Loss: 1.8617, Valid MER: 0.1050
# Epoch [10/50], Train Loss: 1.5649, Train MER: 0.1041, Valid Loss: 1.8729, Valid MER: 0.1024
# Epoch [11/50], Train Loss: 1.5383, Train MER: 0.0989, Valid Loss: 1.8876, Valid MER: 0.1191
# Epoch [12/50], Train Loss: 1.5317, Train MER: 0.1027, Valid Loss: 1.8728, Valid MER: 0.1141
# Epoch [13/50], Train Loss: 1.4561, Train MER: 0.0996, Valid Loss: 2.0408, Valid MER: 0.1056
# Epoch [14/50], Train Loss: 1.4395, Train MER: 0.0998, Valid Loss: 1.9182, Valid MER: 0.1173
# Epoch [15/50], Train Loss: 1.3876, Train MER: 0.0975, Valid Loss: 1.8832, Valid MER: 0.1012
# Epoch [16/50], Train Loss: 1.3542, Train MER: 0.0951, Valid Loss: 1.8902, Valid MER: 0.1083
# Epoch [17/50], Train Loss: 1.3683, Train MER: 0.0979, Valid Loss: 1.9134, Valid MER: 0.0968
# Epoch [18/50], Train Loss: 1.3361, Train MER: 0.0976, Valid Loss: 1.8274, Valid MER: 0.1104
# Epoch [19/50], Train Loss: 1.2692, Train MER: 0.0917, Valid Loss: 1.9255, Valid MER: 0.1163
# Epoch [20/50], Train Loss: 1.2717, Train MER: 0.0955, Valid Loss: 1.7793, Valid MER: 0.0997
# Epoch [21/50], Train Loss: 1.2279, Train MER: 0.0921, Valid Loss: 1.8805, Valid MER: 0.1033
# Epoch [22/50], Train Loss: 1.2047, Train MER: 0.0923, Valid Loss: 1.8048, Valid MER: 0.0991
# Epoch [23/50], Train Loss: 1.2299, Train MER: 0.0939, Valid Loss: 1.7888, Valid MER: 0.0983
# Epoch [24/50], Train Loss: 1.2239, Train MER: 0.0931, Valid Loss: 1.8005, Valid MER: 0.0991
# Epoch [25/50], Train Loss: 1.1489, Train MER: 0.0884, Valid Loss: 2.0327, Valid MER: 0.1148
# Epoch [26/50], Train Loss: 1.1342, Train MER: 0.0893, Valid Loss: 1.9966, Valid MER: 0.1199
# Epoch [27/50], Train Loss: 1.1244, Train MER: 0.0905, Valid Loss: 2.0205, Valid MER: 0.1167
# Epoch [28/50], Train Loss: 1.1305, Train MER: 0.0918, Valid Loss: 1.9086, Valid MER: 0.0992
# Epoch [29/50], Train Loss: 1.0792, Train MER: 0.0879, Valid Loss: 1.8522, Valid MER: 0.1043
# Epoch [30/50], Train Loss: 1.0667, Train MER: 0.0897, Valid Loss: 1.8623, Valid MER: 0.1044
# Epoch [31/50], Train Loss: 1.0588, Train MER: 0.0902, Valid Loss: 2.0260, Valid MER: 0.1067
# Epoch [32/50], Train Loss: 1.0318, Train MER: 0.0853, Valid Loss: 1.9639, Valid MER: 0.1050
# Epoch [33/50], Train Loss: 1.0326, Train MER: 0.0875, Valid Loss: 1.8936, Valid MER: 0.1001
# Epoch [34/50], Train Loss: 0.9918, Train MER: 0.0870, Valid Loss: 1.8710, Valid MER: 0.1095
# Epoch [35/50], Train Loss: 0.9902, Train MER: 0.0853, Valid Loss: 1.9202, Valid MER: 0.1002
# Epoch [36/50], Train Loss: 1.0009, Train MER: 0.0863, Valid Loss: 1.8780, Valid MER: 0.1007
# Epoch [37/50], Train Loss: 0.9861, Train MER: 0.0852, Valid Loss: 1.9419, Valid MER: 0.1071
# Epoch [38/50], Train Loss: 0.9968, Train MER: 0.0877, Valid Loss: 1.9130, Valid MER: 0.1062
# Epoch [39/50], Train Loss: 0.9284, Train MER: 0.0824, Valid Loss: 2.0897, Valid MER: 0.1145
# Epoch [40/50], Train Loss: 0.9418, Train MER: 0.0846, Valid Loss: 1.8520, Valid MER: 0.0984
# Epoch [41/50], Train Loss: 0.9281, Train MER: 0.0832, Valid Loss: 1.8812, Valid MER: 0.1016
# Epoch [42/50], Train Loss: 0.9243, Train MER: 0.0829, Valid Loss: 1.9141, Valid MER: 0.1062
# Epoch [43/50], Train Loss: 0.9172, Train MER: 0.0834, Valid Loss: 2.0208, Valid MER: 0.1026
# Epoch [44/50], Train Loss: 0.8712, Train MER: 0.0801, Valid Loss: 1.9884, Valid MER: 0.1084
# Epoch [45/50], Train Loss: 0.8557, Train MER: 0.0813, Valid Loss: 1.9798, Valid MER: 0.1137
# Epoch [46/50], Train Loss: 0.8624, Train MER: 0.0822, Valid Loss: 1.9730, Valid MER: 0.1013
# Epoch [47/50], Train Loss: 0.8344, Train MER: 0.0789, Valid Loss: 1.9474, Valid MER: 0.1070
# Epoch [48/50], Train Loss: 0.8340, Train MER: 0.0786, Valid Loss: 2.0118, Valid MER: 0.1018
# Epoch [49/50], Train Loss: 0.8271, Train MER: 0.0787, Valid Loss: 2.0674, Valid MER: 0.1059
# Epoch [50/50], Train Loss: 0.8226, Train MER: 0.0796, Valid Loss: 2.0260, Valid MER: 0.1022

# %%
#TODO: Write code to plot the training and validation error (MER) over epochs

# Plotting the validation MER over epochs
plt.plot(train_mers, label='Training MER')
plt.plot(valid_mers, label='Validation MER')
plt.xlabel('Epoch')
plt.ylabel('Median Error Rate (MER)')
plt.title('Training and Validation Error (MER) over Epochs')
plt.legend()
plt.show()

# Print the last value of validation MER
print(valid_mers[-1])
# Out:
# 0.10217872

# %% [markdown]
# ---
# ## Change network architecture

# %% [markdown]
# In the following, build a MLP with 4 hidden layer of sizes 512, 256, 128, 64, respectively.

# %%
#TODO: building a MLP with 4 hidden layer of sizes 512, 256, 128, 64,

import torch.nn as nn
model = nn.Sequential(
    nn.Linear(train_features.shape[1], 512),  # First hidden layer (512 neurons)
    nn.ReLU(),
    nn.Linear(512, 256),  # Second hidden layer (256 neurons)
    nn.ReLU(),
    nn.Linear(256, 128),  # Third hidden layer (128 neurons)
    nn.ReLU(),
    nn.Linear(128, 64),  # Fourth hidden layer (64 neurons)
    nn.ReLU(),
    nn.Linear(64, 1)  # Output layer (1 neuron for regression)
)

model
model = model.to(device)

# %%
#TODO: plot the training and validation error (MER) over epochs

#TODO: write code to train the MLP network and save training and validation error.
# Training loop
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
epochs = 50
train_losses = []
valid_losses = []
train_mers = []
valid_mers = []

for e in range(epochs):
    running_train_loss = 0
    all_train_preds = []  # List to store predictions for the epoch
    all_train_labels = []  # List to store targets for the epoch

    # Training loop for one epoch
    model.train()  # Set the model to training mode
    for train_features, train_labels in train_loader:
        train_features = train_features.to(device)
        train_labels = train_labels.to(device)

        # Forward pass
        output = model(train_features)
        loss = criterion(output, train_labels)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Accumulate training loss
        running_train_loss += loss.item()

        # Collect predictions and labels for MER calculation
        all_train_preds.extend(output.cpu().detach().numpy().flatten())
        all_train_labels.extend(train_labels.cpu().numpy().flatten())

    # Calculate average training loss for the epoch
    epoch_train_loss = running_train_loss / len(train_loader)
    train_losses.append(epoch_train_loss)

    # Calculate training MER
    train_mer = calculate_mer(np.array(all_train_preds), np.array(all_train_labels))
    train_mers.append(train_mer)

    # Validation loop for one epoch
    model.eval()  # Set the model to evaluation mode
    running_valid_loss = 0.0
    all_valid_preds = []
    all_valid_labels = []

    with torch.no_grad():  # Disable gradient calculation during validation
        for valid_features, valid_labels in valid_loader:
            valid_features = valid_features.to(device)
            valid_labels = valid_labels.to(device)

            # Forward pass
            outputs = model(valid_features)
            loss = criterion(outputs, valid_labels)
            running_valid_loss += loss.item()

            # Collect predictions and labels for MER calculation
            all_valid_preds.extend(outputs.cpu().numpy().flatten())
            all_valid_labels.extend(valid_labels.cpu().numpy().flatten())

    # Calculate average validation loss for the epoch
    epoch_valid_loss = running_valid_loss / len(valid_loader)
    valid_losses.append(epoch_valid_loss)

    # Calculate validation MER
    valid_mer = calculate_mer(np.array(all_valid_preds), np.array(all_valid_labels))
    valid_mers.append(valid_mer)

    print(f'Epoch [{e + 1}/{epochs}], Train Loss: {epoch_train_loss:.4f}, Train MER: {train_mer:.4f}, Valid Loss: {epoch_valid_loss:.4f}, Valid MER: {valid_mer:.4f}')
# Out:
# Epoch [1/50], Train Loss: 1.1356, Train MER: 0.0968, Valid Loss: 1.8257, Valid MER: 0.1001
# Epoch [2/50], Train Loss: 1.0853, Train MER: 0.0928, Valid Loss: 1.9017, Valid MER: 0.1080
# Epoch [3/50], Train Loss: 1.0650, Train MER: 0.0914, Valid Loss: 1.8859, Valid MER: 0.0993
# Epoch [4/50], Train Loss: 1.0199, Train MER: 0.0903, Valid Loss: 1.9529, Valid MER: 0.1017
# Epoch [5/50], Train Loss: 1.0371, Train MER: 0.0923, Valid Loss: 1.8583, Valid MER: 0.1143
# Epoch [6/50], Train Loss: 0.9667, Train MER: 0.0875, Valid Loss: 1.8307, Valid MER: 0.1017
# Epoch [7/50], Train Loss: 0.9872, Train MER: 0.0908, Valid Loss: 2.0445, Valid MER: 0.1059
# Epoch [8/50], Train Loss: 0.9195, Train MER: 0.0849, Valid Loss: 2.1075, Valid MER: 0.1168
# Epoch [9/50], Train Loss: 0.9363, Train MER: 0.0858, Valid Loss: 1.9495, Valid MER: 0.1068
# Epoch [10/50], Train Loss: 0.9122, Train MER: 0.0842, Valid Loss: 2.0170, Valid MER: 0.1138
# Epoch [11/50], Train Loss: 0.8445, Train MER: 0.0814, Valid Loss: 1.9268, Valid MER: 0.1044
# Epoch [12/50], Train Loss: 0.8457, Train MER: 0.0820, Valid Loss: 1.9765, Valid MER: 0.1001
# Epoch [13/50], Train Loss: 0.8716, Train MER: 0.0846, Valid Loss: 2.0109, Valid MER: 0.1115
# Epoch [14/50], Train Loss: 0.8102, Train MER: 0.0792, Valid Loss: 2.3540, Valid MER: 0.1250
# Epoch [15/50], Train Loss: 0.8281, Train MER: 0.0807, Valid Loss: 2.1011, Valid MER: 0.1039
# Epoch [16/50], Train Loss: 0.8033, Train MER: 0.0790, Valid Loss: 1.9836, Valid MER: 0.0978
# Epoch [17/50], Train Loss: 0.7727, Train MER: 0.0779, Valid Loss: 1.9395, Valid MER: 0.1054
# Epoch [18/50], Train Loss: 0.7390, Train MER: 0.0774, Valid Loss: 1.9989, Valid MER: 0.0954
# Epoch [19/50], Train Loss: 0.7692, Train MER: 0.0790, Valid Loss: 1.9430, Valid MER: 0.0967
# Epoch [20/50], Train Loss: 0.7417, Train MER: 0.0786, Valid Loss: 1.9693, Valid MER: 0.1003
# Epoch [21/50], Train Loss: 0.7333, Train MER: 0.0780, Valid Loss: 1.9144, Valid MER: 0.0983
# Epoch [22/50], Train Loss: 0.7125, Train MER: 0.0748, Valid Loss: 1.8896, Valid MER: 0.1011
# Epoch [23/50], Train Loss: 0.7144, Train MER: 0.0781, Valid Loss: 1.9534, Valid MER: 0.0953
# Epoch [24/50], Train Loss: 0.6641, Train MER: 0.0723, Valid Loss: 2.1457, Valid MER: 0.0994
# Epoch [25/50], Train Loss: 0.6882, Train MER: 0.0733, Valid Loss: 2.0877, Valid MER: 0.1026
# Epoch [26/50], Train Loss: 0.7199, Train MER: 0.0780, Valid Loss: 2.0002, Valid MER: 0.0957
# Epoch [27/50], Train Loss: 0.6669, Train MER: 0.0726, Valid Loss: 2.2015, Valid MER: 0.1005
# Epoch [28/50], Train Loss: 0.6688, Train MER: 0.0739, Valid Loss: 1.9680, Valid MER: 0.0975
# Epoch [29/50], Train Loss: 0.6511, Train MER: 0.0704, Valid Loss: 2.0265, Valid MER: 0.1032
# Epoch [30/50], Train Loss: 0.6161, Train MER: 0.0696, Valid Loss: 2.0747, Valid MER: 0.0983
# Epoch [31/50], Train Loss: 0.6178, Train MER: 0.0720, Valid Loss: 2.1919, Valid MER: 0.1091
# Epoch [32/50], Train Loss: 0.6117, Train MER: 0.0695, Valid Loss: 2.0025, Valid MER: 0.0986
# Epoch [33/50], Train Loss: 0.5814, Train MER: 0.0679, Valid Loss: 2.0629, Valid MER: 0.0990
# Epoch [34/50], Train Loss: 0.6030, Train MER: 0.0702, Valid Loss: 2.0034, Valid MER: 0.0964
# Epoch [35/50], Train Loss: 0.5683, Train MER: 0.0668, Valid Loss: 2.0507, Valid MER: 0.0976
# Epoch [36/50], Train Loss: 0.5700, Train MER: 0.0661, Valid Loss: 1.9917, Valid MER: 0.0973
# Epoch [37/50], Train Loss: 0.5546, Train MER: 0.0660, Valid Loss: 2.0679, Valid MER: 0.1026
# Epoch [38/50], Train Loss: 0.5352, Train MER: 0.0642, Valid Loss: 2.1503, Valid MER: 0.0982
# Epoch [39/50], Train Loss: 0.5530, Train MER: 0.0648, Valid Loss: 2.0483, Valid MER: 0.0967
# Epoch [40/50], Train Loss: 0.5415, Train MER: 0.0641, Valid Loss: 2.1329, Valid MER: 0.1090
# Epoch [41/50], Train Loss: 0.5605, Train MER: 0.0676, Valid Loss: 2.1386, Valid MER: 0.0979
# Epoch [42/50], Train Loss: 0.5509, Train MER: 0.0656, Valid Loss: 2.0072, Valid MER: 0.0966
# Epoch [43/50], Train Loss: 0.5347, Train MER: 0.0636, Valid Loss: 2.0487, Valid MER: 0.1008
# Epoch [44/50], Train Loss: 0.5563, Train MER: 0.0649, Valid Loss: 2.0779, Valid MER: 0.0973
# Epoch [45/50], Train Loss: 0.5489, Train MER: 0.0656, Valid Loss: 2.0699, Valid MER: 0.1016
# Epoch [46/50], Train Loss: 0.5480, Train MER: 0.0640, Valid Loss: 2.0138, Valid MER: 0.0992
# Epoch [47/50], Train Loss: 0.4937, Train MER: 0.0632, Valid Loss: 2.0381, Valid MER: 0.0921
# Epoch [48/50], Train Loss: 0.5032, Train MER: 0.0605, Valid Loss: 2.1431, Valid MER: 0.0979
# Epoch [49/50], Train Loss: 0.5077, Train MER: 0.0612, Valid Loss: 2.2952, Valid MER: 0.1107
# Epoch [50/50], Train Loss: 0.5241, Train MER: 0.0625, Valid Loss: 2.1533, Valid MER: 0.0996

# %%
#TODO: Write code to plot the training and validation error (MER) over epochs

# Plotting the validation MER over epochs
plt.plot(train_mers, label='Training MER')
plt.plot(valid_mers, label='Validation MER')
plt.xlabel('Epoch')
plt.ylabel('Median Error Rate (MER)')
plt.title('Training and Validation Error (MER) over Epochs')
plt.legend()
plt.show()

# Print the last value of validation MER
print(valid_mers[-1])
# Out:
# 0.09956135

# %% [markdown]
# ---
# ## Add norm regularization
#
# In the following, use the norm regularization to retrain the above MLP.

# %%
#TODO: plot the training and validation error (MER) over epochs after using norm regularization

model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.01)
epochs = 50
train_losses = []
valid_losses = []
train_mers = []
valid_mers = []

for e in range(epochs):
    running_train_loss = 0
    all_train_preds = []  # List to store predictions for the epoch
    all_train_labels = []  # List to store targets for the epoch

    # Training loop for one epoch
    model.train()  # Set the model to training mode
    for train_features, train_labels in train_loader:
        train_features = train_features.to(device)
        train_labels = train_labels.to(device)

        # Forward pass
        output = model(train_features)
        loss = criterion(output, train_labels)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Accumulate training loss
        running_train_loss += loss.item()

        # Collect predictions and labels for MER calculation
        all_train_preds.extend(output.cpu().detach().numpy().flatten())
        all_train_labels.extend(train_labels.cpu().numpy().flatten())

    # Calculate average training loss for the epoch
    epoch_train_loss = running_train_loss / len(train_loader)
    train_losses.append(epoch_train_loss)

    # Calculate training MER
    train_mer = calculate_mer(np.array(all_train_preds), np.array(all_train_labels))
    train_mers.append(train_mer)

    # Validation loop for one epoch
    model.eval()  # Set the model to evaluation mode
    running_valid_loss = 0.0
    all_valid_preds = []
    all_valid_labels = []

    with torch.no_grad():  # Disable gradient calculation during validation
        for valid_features, valid_labels in valid_loader:
            valid_features = valid_features.to(device)
            valid_labels = valid_labels.to(device)

            # Forward pass
            outputs = model(valid_features)
            loss = criterion(outputs, valid_labels)
            running_valid_loss += loss.item()

            # Collect predictions and labels for MER calculation
            all_valid_preds.extend(outputs.cpu().numpy().flatten())
            all_valid_labels.extend(valid_labels.cpu().numpy().flatten())

    # Calculate average validation loss for the epoch
    epoch_valid_loss = running_valid_loss / len(valid_loader)
    valid_losses.append(epoch_valid_loss)

    # Calculate validation MER
    valid_mer = calculate_mer(np.array(all_valid_preds), np.array(all_valid_labels))
    valid_mers.append(valid_mer)

    print(f'Epoch [{e + 1}/{epochs}], Train Loss: {epoch_train_loss:.4f}, Train MER: {train_mer:.4f}, Valid Loss: {epoch_valid_loss:.4f}, Valid MER: {valid_mer:.4f}')
# Out:
# Epoch [1/50], Train Loss: 0.8458, Train MER: 0.0928, Valid Loss: 1.9121, Valid MER: 0.1025
# Epoch [2/50], Train Loss: 0.7929, Train MER: 0.0879, Valid Loss: 1.9729, Valid MER: 0.1059
# Epoch [3/50], Train Loss: 0.7452, Train MER: 0.0875, Valid Loss: 1.9632, Valid MER: 0.1057
# Epoch [4/50], Train Loss: 0.7620, Train MER: 0.0880, Valid Loss: 1.9165, Valid MER: 0.1020
# Epoch [5/50], Train Loss: 0.8026, Train MER: 0.0896, Valid Loss: 2.0970, Valid MER: 0.1094
# Epoch [6/50], Train Loss: 0.7664, Train MER: 0.0880, Valid Loss: 2.0487, Valid MER: 0.1167
# Epoch [7/50], Train Loss: 0.7647, Train MER: 0.0891, Valid Loss: 2.0243, Valid MER: 0.1092
# Epoch [8/50], Train Loss: 0.7902, Train MER: 0.0887, Valid Loss: 1.9597, Valid MER: 0.1099
# Epoch [9/50], Train Loss: 0.7134, Train MER: 0.0856, Valid Loss: 1.9115, Valid MER: 0.1021
# Epoch [10/50], Train Loss: 0.7469, Train MER: 0.0872, Valid Loss: 1.9137, Valid MER: 0.0957
# Epoch [11/50], Train Loss: 0.7282, Train MER: 0.0874, Valid Loss: 2.0023, Valid MER: 0.1053
# Epoch [12/50], Train Loss: 0.7632, Train MER: 0.0873, Valid Loss: 1.9504, Valid MER: 0.1071
# Epoch [13/50], Train Loss: 0.7553, Train MER: 0.0883, Valid Loss: 1.9567, Valid MER: 0.1025
# Epoch [14/50], Train Loss: 0.7225, Train MER: 0.0856, Valid Loss: 1.9099, Valid MER: 0.1019
# Epoch [15/50], Train Loss: 0.7696, Train MER: 0.0887, Valid Loss: 1.9749, Valid MER: 0.1058
# Epoch [16/50], Train Loss: 0.7234, Train MER: 0.0833, Valid Loss: 1.9680, Valid MER: 0.1010
# Epoch [17/50], Train Loss: 0.7150, Train MER: 0.0848, Valid Loss: 1.9101, Valid MER: 0.1016
# Epoch [18/50], Train Loss: 0.7335, Train MER: 0.0865, Valid Loss: 1.9703, Valid MER: 0.0987
# Epoch [19/50], Train Loss: 0.7540, Train MER: 0.0865, Valid Loss: 2.1038, Valid MER: 0.1098
# Epoch [20/50], Train Loss: 0.7332, Train MER: 0.0859, Valid Loss: 2.0660, Valid MER: 0.1078
# Epoch [21/50], Train Loss: 0.7261, Train MER: 0.0869, Valid Loss: 1.9427, Valid MER: 0.1029
# Epoch [22/50], Train Loss: 0.7010, Train MER: 0.0834, Valid Loss: 2.1222, Valid MER: 0.1061
# Epoch [23/50], Train Loss: 0.7369, Train MER: 0.0862, Valid Loss: 2.0661, Valid MER: 0.1068
# Epoch [24/50], Train Loss: 0.7440, Train MER: 0.0858, Valid Loss: 2.0599, Valid MER: 0.1099
# Epoch [25/50], Train Loss: 0.7172, Train MER: 0.0856, Valid Loss: 2.0638, Valid MER: 0.1049
# Epoch [26/50], Train Loss: 0.7307, Train MER: 0.0830, Valid Loss: 1.9103, Valid MER: 0.1021
# Epoch [27/50], Train Loss: 0.7334, Train MER: 0.0861, Valid Loss: 1.9523, Valid MER: 0.1021
# Epoch [28/50], Train Loss: 0.7241, Train MER: 0.0855, Valid Loss: 2.0326, Valid MER: 0.0987
# Epoch [29/50], Train Loss: 0.7021, Train MER: 0.0846, Valid Loss: 2.1636, Valid MER: 0.1076
# Epoch [30/50], Train Loss: 0.7217, Train MER: 0.0860, Valid Loss: 1.8508, Valid MER: 0.1010
# Epoch [31/50], Train Loss: 0.6993, Train MER: 0.0844, Valid Loss: 2.0228, Valid MER: 0.1037
# Epoch [32/50], Train Loss: 0.6932, Train MER: 0.0839, Valid Loss: 2.0276, Valid MER: 0.1031
# Epoch [33/50], Train Loss: 0.7254, Train MER: 0.0849, Valid Loss: 1.9537, Valid MER: 0.1046
# Epoch [34/50], Train Loss: 0.7322, Train MER: 0.0871, Valid Loss: 1.9337, Valid MER: 0.1007
# Epoch [35/50], Train Loss: 0.6819, Train MER: 0.0832, Valid Loss: 2.0056, Valid MER: 0.0987
# Epoch [36/50], Train Loss: 0.7079, Train MER: 0.0847, Valid Loss: 1.9048, Valid MER: 0.1010
# Epoch [37/50], Train Loss: 0.6820, Train MER: 0.0843, Valid Loss: 2.0733, Valid MER: 0.1074
# Epoch [38/50], Train Loss: 0.7027, Train MER: 0.0848, Valid Loss: 1.9887, Valid MER: 0.0999
# Epoch [39/50], Train Loss: 0.7601, Train MER: 0.0871, Valid Loss: 2.0947, Valid MER: 0.1062
# Epoch [40/50], Train Loss: 0.7589, Train MER: 0.0861, Valid Loss: 1.9481, Valid MER: 0.1049
# Epoch [41/50], Train Loss: 0.6969, Train MER: 0.0827, Valid Loss: 2.0688, Valid MER: 0.0979
# Epoch [42/50], Train Loss: 0.6763, Train MER: 0.0832, Valid Loss: 1.9575, Valid MER: 0.1086
# Epoch [43/50], Train Loss: 0.7099, Train MER: 0.0839, Valid Loss: 2.0634, Valid MER: 0.1016
# Epoch [44/50], Train Loss: 0.6926, Train MER: 0.0828, Valid Loss: 1.9455, Valid MER: 0.1029
# Epoch [45/50], Train Loss: 0.7023, Train MER: 0.0841, Valid Loss: 2.0373, Valid MER: 0.1000
# Epoch [46/50], Train Loss: 0.7289, Train MER: 0.0851, Valid Loss: 1.8876, Valid MER: 0.0964
# Epoch [47/50], Train Loss: 0.6769, Train MER: 0.0841, Valid Loss: 1.9525, Valid MER: 0.1074
# Epoch [48/50], Train Loss: 0.7177, Train MER: 0.0849, Valid Loss: 1.9009, Valid MER: 0.0981
# Epoch [49/50], Train Loss: 0.7034, Train MER: 0.0834, Valid Loss: 2.1151, Valid MER: 0.1085
# Epoch [50/50], Train Loss: 0.7060, Train MER: 0.0858, Valid Loss: 1.9287, Valid MER: 0.0985

# %%
#TODO: Write code to plot the training and validation error (MER) over epochs

# Plotting the validation MER over epochs
plt.plot(train_mers, label='Training MER')
plt.plot(valid_mers, label='Validation MER')
plt.xlabel('Epoch')
plt.ylabel('Median Error Rate (MER)')
plt.title('Training and Validation Error (MER) over Epochs')
plt.legend()
plt.show()

# Print the last value of validation MER
print(valid_mers[-1])
# Out:
# 0.09847778

# %% [markdown]
# ---
# ## Add dropout layer
#
# In the following, add dropout layer to the above MLP.

# %%
#TODO: plot the training and validation error (MER) over epochs after using norm regularization

import torch.nn as nn
model = nn.Sequential(
    nn.Linear(train_features.shape[1], 512),
    nn.ReLU(),
    nn.Dropout(p=0.2),  # Dropout layer after first hidden layer
    nn.Linear(512, 256),
    nn.ReLU(),
    nn.Dropout(p=0.2),  # Dropout layer after second hidden layer
    nn.Linear(256, 128),
    nn.ReLU(),
    nn.Dropout(p=0.2),  # Dropout layer after third hidden layer
    nn.Linear(128, 64),
    nn.ReLU(),
    nn.Dropout(p=0.2),  # Dropout layer after fourth hidden layer
    nn.Linear(64, 1)
)

model
model = model.to(device)

# %%
#TODO: plot the training and validation error (MER) over epochs after using norm regularization

model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.01)
epochs = 50
train_losses = []
valid_losses = []
train_mers = []
valid_mers = []

for e in range(epochs):
    running_train_loss = 0
    all_train_preds = []  # List to store predictions for the epoch
    all_train_labels = []  # List to store targets for the epoch

    # Training loop for one epoch
    model.train()  # Set the model to training mode
    for train_features, train_labels in train_loader:
        train_features = train_features.to(device)
        train_labels = train_labels.to(device)

        # Forward pass
        output = model(train_features)
        loss = criterion(output, train_labels)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Accumulate training loss
        running_train_loss += loss.item()

        # Collect predictions and labels for MER calculation
        all_train_preds.extend(output.cpu().detach().numpy().flatten())
        all_train_labels.extend(train_labels.cpu().numpy().flatten())

    # Calculate average training loss for the epoch
    epoch_train_loss = running_train_loss / len(train_loader)
    train_losses.append(epoch_train_loss)

    # Calculate training MER
    train_mer = calculate_mer(np.array(all_train_preds), np.array(all_train_labels))
    train_mers.append(train_mer)

    # Validation loop for one epoch
    model.eval()  # Set the model to evaluation mode
    running_valid_loss = 0.0
    all_valid_preds = []
    all_valid_labels = []

    with torch.no_grad():  # Disable gradient calculation during validation
        for valid_features, valid_labels in valid_loader:
            valid_features = valid_features.to(device)
            valid_labels = valid_labels.to(device)

            # Forward pass
            outputs = model(valid_features)
            loss = criterion(outputs, valid_labels)
            running_valid_loss += loss.item()

            # Collect predictions and labels for MER calculation
            all_valid_preds.extend(outputs.cpu().numpy().flatten())
            all_valid_labels.extend(valid_labels.cpu().numpy().flatten())

    # Calculate average validation loss for the epoch
    epoch_valid_loss = running_valid_loss / len(valid_loader)
    valid_losses.append(epoch_valid_loss)

    # Calculate validation MER
    valid_mer = calculate_mer(np.array(all_valid_preds), np.array(all_valid_labels))
    valid_mers.append(valid_mer)

    print(f'Epoch [{e + 1}/{epochs}], Train Loss: {epoch_train_loss:.4f}, Train MER: {train_mer:.4f}, Valid Loss: {epoch_valid_loss:.4f}, Valid MER: {valid_mer:.4f}')
# Out:
# Epoch [1/50], Train Loss: 2.5880, Train MER: 0.1611, Valid Loss: 2.0869, Valid MER: 0.1211
# Epoch [2/50], Train Loss: 2.5428, Train MER: 0.1567, Valid Loss: 2.2325, Valid MER: 0.1270
# Epoch [3/50], Train Loss: 2.4727, Train MER: 0.1527, Valid Loss: 2.3605, Valid MER: 0.1345
# Epoch [4/50], Train Loss: 2.3384, Train MER: 0.1452, Valid Loss: 2.1889, Valid MER: 0.1444
# Epoch [5/50], Train Loss: 2.3209, Train MER: 0.1457, Valid Loss: 1.9990, Valid MER: 0.1118
# Epoch [6/50], Train Loss: 2.2182, Train MER: 0.1437, Valid Loss: 2.1998, Valid MER: 0.1273
# Epoch [7/50], Train Loss: 2.1651, Train MER: 0.1385, Valid Loss: 1.8852, Valid MER: 0.1062
# Epoch [8/50], Train Loss: 2.1366, Train MER: 0.1392, Valid Loss: 1.9601, Valid MER: 0.1071
# Epoch [9/50], Train Loss: 2.2171, Train MER: 0.1375, Valid Loss: 1.8762, Valid MER: 0.1087
# Epoch [10/50], Train Loss: 2.1692, Train MER: 0.1364, Valid Loss: 1.9315, Valid MER: 0.1041
# Epoch [11/50], Train Loss: 2.1007, Train MER: 0.1342, Valid Loss: 2.0638, Valid MER: 0.1134
# Epoch [12/50], Train Loss: 2.0909, Train MER: 0.1326, Valid Loss: 1.8382, Valid MER: 0.1062
# Epoch [13/50], Train Loss: 2.0505, Train MER: 0.1327, Valid Loss: 1.7996, Valid MER: 0.0995
# Epoch [14/50], Train Loss: 1.9873, Train MER: 0.1277, Valid Loss: 1.9124, Valid MER: 0.1254
# Epoch [15/50], Train Loss: 1.9752, Train MER: 0.1335, Valid Loss: 1.7586, Valid MER: 0.1033
# Epoch [16/50], Train Loss: 1.9047, Train MER: 0.1303, Valid Loss: 1.7771, Valid MER: 0.1029
# Epoch [17/50], Train Loss: 1.9601, Train MER: 0.1261, Valid Loss: 1.8194, Valid MER: 0.1027
# Epoch [18/50], Train Loss: 1.9177, Train MER: 0.1306, Valid Loss: 1.8048, Valid MER: 0.1071
# Epoch [19/50], Train Loss: 1.9177, Train MER: 0.1274, Valid Loss: 2.0166, Valid MER: 0.1092
# Epoch [20/50], Train Loss: 1.9105, Train MER: 0.1302, Valid Loss: 1.9028, Valid MER: 0.1110
# Epoch [21/50], Train Loss: 1.8494, Train MER: 0.1259, Valid Loss: 1.8327, Valid MER: 0.1191
# Epoch [22/50], Train Loss: 1.8302, Train MER: 0.1260, Valid Loss: 1.8437, Valid MER: 0.1031
# Epoch [23/50], Train Loss: 1.8516, Train MER: 0.1266, Valid Loss: 1.9810, Valid MER: 0.1210
# Epoch [24/50], Train Loss: 1.7871, Train MER: 0.1245, Valid Loss: 1.9169, Valid MER: 0.1195
# Epoch [25/50], Train Loss: 1.8177, Train MER: 0.1265, Valid Loss: 1.7278, Valid MER: 0.1023
# Epoch [26/50], Train Loss: 1.8464, Train MER: 0.1306, Valid Loss: 1.8559, Valid MER: 0.1108
# Epoch [27/50], Train Loss: 1.7477, Train MER: 0.1278, Valid Loss: 1.7924, Valid MER: 0.1067
# Epoch [28/50], Train Loss: 1.8356, Train MER: 0.1274, Valid Loss: 1.8062, Valid MER: 0.1085
# Epoch [29/50], Train Loss: 1.7880, Train MER: 0.1268, Valid Loss: 2.2326, Valid MER: 0.1193
# Epoch [30/50], Train Loss: 1.7602, Train MER: 0.1274, Valid Loss: 1.8901, Valid MER: 0.1045
# Epoch [31/50], Train Loss: 1.7284, Train MER: 0.1226, Valid Loss: 1.9206, Valid MER: 0.1088
# Epoch [32/50], Train Loss: 1.8214, Train MER: 0.1264, Valid Loss: 1.8961, Valid MER: 0.1032
# Epoch [33/50], Train Loss: 1.7494, Train MER: 0.1231, Valid Loss: 1.9323, Valid MER: 0.1033
# Epoch [34/50], Train Loss: 1.6812, Train MER: 0.1230, Valid Loss: 1.7612, Valid MER: 0.1072
# Epoch [35/50], Train Loss: 1.7133, Train MER: 0.1258, Valid Loss: 1.9027, Valid MER: 0.1154
# Epoch [36/50], Train Loss: 1.7151, Train MER: 0.1236, Valid Loss: 1.9085, Valid MER: 0.1032
# Epoch [37/50], Train Loss: 1.7061, Train MER: 0.1229, Valid Loss: 1.7677, Valid MER: 0.1122
# Epoch [38/50], Train Loss: 1.6588, Train MER: 0.1210, Valid Loss: 1.8712, Valid MER: 0.1008
# Epoch [39/50], Train Loss: 1.6756, Train MER: 0.1217, Valid Loss: 1.8123, Valid MER: 0.1035
# Epoch [40/50], Train Loss: 1.6939, Train MER: 0.1261, Valid Loss: 2.1120, Valid MER: 0.1084
# Epoch [41/50], Train Loss: 1.6414, Train MER: 0.1230, Valid Loss: 1.9175, Valid MER: 0.1079
# Epoch [42/50], Train Loss: 1.6530, Train MER: 0.1240, Valid Loss: 1.8127, Valid MER: 0.1054
# Epoch [43/50], Train Loss: 1.6909, Train MER: 0.1240, Valid Loss: 1.8585, Valid MER: 0.1065
# Epoch [44/50], Train Loss: 1.7181, Train MER: 0.1235, Valid Loss: 1.7627, Valid MER: 0.1086
# Epoch [45/50], Train Loss: 1.6381, Train MER: 0.1222, Valid Loss: 1.9341, Valid MER: 0.1064
# Epoch [46/50], Train Loss: 1.7051, Train MER: 0.1231, Valid Loss: 1.9190, Valid MER: 0.1067
# Epoch [47/50], Train Loss: 1.6044, Train MER: 0.1204, Valid Loss: 1.7874, Valid MER: 0.1009
# Epoch [48/50], Train Loss: 1.5943, Train MER: 0.1208, Valid Loss: 1.7892, Valid MER: 0.1004
# Epoch [49/50], Train Loss: 1.6209, Train MER: 0.1211, Valid Loss: 1.7733, Valid MER: 0.0972
# Epoch [50/50], Train Loss: 1.5253, Train MER: 0.1177, Valid Loss: 1.7487, Valid MER: 0.1045

# %%
plt.plot(train_mers, label='Training MER')
plt.plot(valid_mers, label='Validation MER')
plt.xlabel('Epoch')
plt.ylabel('Median Error Rate (MER)')
plt.title('Training and Validation Error (MER) over Epochs')
plt.legend()
plt.show()
# Print the last value of validation MER
print(valid_mers[-1])
# Out:
# 0.10446977

# %% [markdown]
# ## Some other model variations
#
# **You're more than welcome to try some other model varations (e.g. different number of hidden layers, hidden neurons, learning rate, etc) to achieve lower valid error. Include a table listing all the model hyperparameters that you have tried with the corresponding validation errors that you found.**

# %%
#TODO: plot the training and validation error (MER) over epochs after using norm regularization

import torch.nn as nn
model = nn.Sequential(
    nn.Linear(train_features.shape[1], 512),
    nn.ReLU(),
    nn.Dropout(p=0.15),  # Dropout layer after first hidden layer
    nn.Linear(512, 256),
    nn.ReLU(),
    nn.Dropout(p=0.15),  # Dropout layer after second hidden layer
    nn.Linear(256, 128),
    nn.ReLU(),
    nn.Dropout(p=0.15),  # Dropout layer after third hidden layer
    nn.Linear(128, 64),
    nn.ReLU(),
    nn.Dropout(p=0.15),  # Dropout layer after fourth hidden layer
    nn.Linear(64, 1)
)

model = model.to(device)

criterion = nn.L1Loss()

#TODO: plot the training and validation error (MER) over epochs after using norm regularization

model.to(device)
#optimizer = torch.optim.Adam(model.parameters(), lr=0.005, weight_decay=0.0001)
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, weight_decay = 0.0005, momentum=0.9)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.5)
epochs = 200
train_losses = []
valid_losses = []
train_mers = []
valid_mers = []

for e in range(epochs):
    running_train_loss = 0
    all_train_preds = []  # List to store predictions for the epoch
    all_train_labels = []  # List to store targets for the epoch

    # Training loop for one epoch
    model.train()  # Set the model to training mode
    for train_features, train_labels in train_loader:
        train_features = train_features.to(device)
        train_labels = train_labels.to(device)

        # Forward pass
        output = model(train_features)
        loss = criterion(output, train_labels)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Accumulate training loss
        running_train_loss += loss.item()

        # Collect predictions and labels for MER calculation
        all_train_preds.extend(output.cpu().detach().numpy().flatten())
        all_train_labels.extend(train_labels.cpu().numpy().flatten())

    # Calculate average training loss for the epoch
    epoch_train_loss = running_train_loss / len(train_loader)
    train_losses.append(epoch_train_loss)

    # Calculate training MER
    train_mer = calculate_mer(np.array(all_train_preds), np.array(all_train_labels))
    train_mers.append(train_mer)

    scheduler.step()

    # Validation loop for one epoch
    model.eval()  # Set the model to evaluation mode
    running_valid_loss = 0.0
    all_valid_preds = []
    all_valid_labels = []

    with torch.no_grad():  # Disable gradient calculation during validation
        for valid_features, valid_labels in valid_loader:
            valid_features = valid_features.to(device)
            valid_labels = valid_labels.to(device)

            # Forward pass
            outputs = model(valid_features)
            loss = criterion(outputs, valid_labels)
            running_valid_loss += loss.item()

            # Collect predictions and labels for MER calculation
            all_valid_preds.extend(outputs.cpu().numpy().flatten())
            all_valid_labels.extend(valid_labels.cpu().numpy().flatten())

    # Calculate average validation loss for the epoch
    epoch_valid_loss = running_valid_loss / len(valid_loader)
    valid_losses.append(epoch_valid_loss)

    # Calculate validation MER
    valid_mer = calculate_mer(np.array(all_valid_preds), np.array(all_valid_labels))
    valid_mers.append(valid_mer)

    print(f'Epoch [{e + 1}/{epochs}], Train Loss: {epoch_train_loss:.4f}, Train MER: {train_mer:.4f}, Valid Loss: {epoch_valid_loss:.4f}, Valid MER: {valid_mer:.4f}')



plt.plot(train_mers, label='Training MER')
plt.plot(valid_mers, label='Validation MER')
plt.xlabel('Epoch')
plt.ylabel('Median Error Rate (MER)')
plt.title('Training and Validation Error (MER) over Epochs')
plt.legend()
plt.show()
# Out:
# Epoch [1/200], Train Loss: 1.5611, Train MER: 0.2228, Valid Loss: 1.0670, Valid MER: 0.1537
# Epoch [2/200], Train Loss: 1.0520, Train MER: 0.1511, Valid Loss: 1.0622, Valid MER: 0.1572
# Epoch [3/200], Train Loss: 0.9585, Train MER: 0.1346, Valid Loss: 0.8877, Valid MER: 0.1212
# Epoch [4/200], Train Loss: 0.9304, Train MER: 0.1283, Valid Loss: 0.9115, Valid MER: 0.1201
# Epoch [5/200], Train Loss: 0.8767, Train MER: 0.1193, Valid Loss: 0.8049, Valid MER: 0.0987
# Epoch [6/200], Train Loss: 0.8745, Train MER: 0.1176, Valid Loss: 0.8233, Valid MER: 0.1042
# Epoch [7/200], Train Loss: 0.8516, Train MER: 0.1105, Valid Loss: 0.8880, Valid MER: 0.1119
# Epoch [8/200], Train Loss: 0.8459, Train MER: 0.1119, Valid Loss: 0.8590, Valid MER: 0.1157
# Epoch [9/200], Train Loss: 0.8332, Train MER: 0.1094, Valid Loss: 0.8161, Valid MER: 0.0977
# Epoch [10/200], Train Loss: 0.8211, Train MER: 0.1077, Valid Loss: 0.9368, Valid MER: 0.1110
# Epoch [11/200], Train Loss: 0.8156, Train MER: 0.1051, Valid Loss: 0.7844, Valid MER: 0.0978
# Epoch [12/200], Train Loss: 0.8214, Train MER: 0.1066, Valid Loss: 0.8043, Valid MER: 0.0996
# Epoch [13/200], Train Loss: 0.7953, Train MER: 0.1047, Valid Loss: 0.7847, Valid MER: 0.0972
# Epoch [14/200], Train Loss: 0.7948, Train MER: 0.1027, Valid Loss: 0.7794, Valid MER: 0.0970
# Epoch [15/200], Train Loss: 0.8035, Train MER: 0.1051, Valid Loss: 0.8259, Valid MER: 0.0993
# Epoch [16/200], Train Loss: 0.7828, Train MER: 0.1022, Valid Loss: 0.7997, Valid MER: 0.1000
# Epoch [17/200], Train Loss: 0.7924, Train MER: 0.1008, Valid Loss: 0.7860, Valid MER: 0.0928
# Epoch [18/200], Train Loss: 0.7863, Train MER: 0.0997, Valid Loss: 0.8154, Valid MER: 0.1017
# Epoch [19/200], Train Loss: 0.7690, Train MER: 0.0981, Valid Loss: 0.9120, Valid MER: 0.1114
# Epoch [20/200], Train Loss: 0.7657, Train MER: 0.0996, Valid Loss: 0.7523, Valid MER: 0.0912
# Epoch [21/200], Train Loss: 0.7676, Train MER: 0.0984, Valid Loss: 0.8166, Valid MER: 0.1042
# Epoch [22/200], Train Loss: 0.7665, Train MER: 0.0993, Valid Loss: 0.7680, Valid MER: 0.0953
# Epoch [23/200], Train Loss: 0.7678, Train MER: 0.0976, Valid Loss: 0.7978, Valid MER: 0.0991
# Epoch [24/200], Train Loss: 0.7573, Train MER: 0.0985, Valid Loss: 0.7696, Valid MER: 0.0983
# Epoch [25/200], Train Loss: 0.7535, Train MER: 0.0966, Valid Loss: 0.7660, Valid MER: 0.0940
# Epoch [26/200], Train Loss: 0.7507, Train MER: 0.0952, Valid Loss: 0.7745, Valid MER: 0.0960
# Epoch [27/200], Train Loss: 0.7493, Train MER: 0.0965, Valid Loss: 0.7651, Valid MER: 0.0936
# Epoch [28/200], Train Loss: 0.7464, Train MER: 0.0962, Valid Loss: 0.8340, Valid MER: 0.1077
# Epoch [29/200], Train Loss: 0.7372, Train MER: 0.0937, Valid Loss: 0.7551, Valid MER: 0.0918
# Epoch [30/200], Train Loss: 0.7524, Train MER: 0.0970, Valid Loss: 0.7533, Valid MER: 0.0936
# Epoch [31/200], Train Loss: 0.7423, Train MER: 0.0919, Valid Loss: 0.7709, Valid MER: 0.0982
# Epoch [32/200], Train Loss: 0.7311, Train MER: 0.0946, Valid Loss: 0.7804, Valid MER: 0.0986
# Epoch [33/200], Train Loss: 0.7361, Train MER: 0.0936, Valid Loss: 0.7792, Valid MER: 0.0969
# Epoch [34/200], Train Loss: 0.7403, Train MER: 0.0947, Valid Loss: 0.7757, Valid MER: 0.0936
# Epoch [35/200], Train Loss: 0.7379, Train MER: 0.0938, Valid Loss: 0.7396, Valid MER: 0.0863
# Epoch [36/200], Train Loss: 0.7278, Train MER: 0.0912, Valid Loss: 0.7751, Valid MER: 0.0946
# Epoch [37/200], Train Loss: 0.7159, Train MER: 0.0903, Valid Loss: 0.7426, Valid MER: 0.0910
# Epoch [38/200], Train Loss: 0.7372, Train MER: 0.0933, Valid Loss: 0.7720, Valid MER: 0.0922
# Epoch [39/200], Train Loss: 0.7331, Train MER: 0.0918, Valid Loss: 0.7846, Valid MER: 0.0956
# Epoch [40/200], Train Loss: 0.7209, Train MER: 0.0921, Valid Loss: 0.7908, Valid MER: 0.0942
# Epoch [41/200], Train Loss: 0.7156, Train MER: 0.0923, Valid Loss: 0.7482, Valid MER: 0.0880
# Epoch [42/200], Train Loss: 0.7111, Train MER: 0.0887, Valid Loss: 0.8152, Valid MER: 0.1124
# Epoch [43/200], Train Loss: 0.7172, Train MER: 0.0914, Valid Loss: 0.7434, Valid MER: 0.0871
# Epoch [44/200], Train Loss: 0.7140, Train MER: 0.0900, Valid Loss: 0.7514, Valid MER: 0.0889
# Epoch [45/200], Train Loss: 0.7089, Train MER: 0.0904, Valid Loss: 0.7672, Valid MER: 0.0931
# Epoch [46/200], Train Loss: 0.7038, Train MER: 0.0898, Valid Loss: 0.7728, Valid MER: 0.0943
# Epoch [47/200], Train Loss: 0.7148, Train MER: 0.0910, Valid Loss: 0.7501, Valid MER: 0.0902
# Epoch [48/200], Train Loss: 0.7109, Train MER: 0.0902, Valid Loss: 0.7667, Valid MER: 0.0879
# Epoch [49/200], Train Loss: 0.7085, Train MER: 0.0892, Valid Loss: 0.7740, Valid MER: 0.0958
# Epoch [50/200], Train Loss: 0.7087, Train MER: 0.0891, Valid Loss: 0.7604, Valid MER: 0.0914
# Epoch [51/200], Train Loss: 0.6705, Train MER: 0.0850, Valid Loss: 0.7476, Valid MER: 0.0876
# Epoch [52/200], Train Loss: 0.6647, Train MER: 0.0823, Valid Loss: 0.7544, Valid MER: 0.0868
# Epoch [53/200], Train Loss: 0.6535, Train MER: 0.0808, Valid Loss: 0.7294, Valid MER: 0.0844
# Epoch [54/200], Train Loss: 0.6460, Train MER: 0.0806, Valid Loss: 0.7500, Valid MER: 0.0876
# Epoch [55/200], Train Loss: 0.6527, Train MER: 0.0811, Valid Loss: 0.7330, Valid MER: 0.0834
# Epoch [56/200], Train Loss: 0.6406, Train MER: 0.0782, Valid Loss: 0.7737, Valid MER: 0.0864
# Epoch [57/200], Train Loss: 0.6396, Train MER: 0.0787, Valid Loss: 0.7186, Valid MER: 0.0828
# Epoch [58/200], Train Loss: 0.6443, Train MER: 0.0799, Valid Loss: 0.7575, Valid MER: 0.0861
# Epoch [59/200], Train Loss: 0.6416, Train MER: 0.0799, Valid Loss: 0.7564, Valid MER: 0.0859
# Epoch [60/200], Train Loss: 0.6405, Train MER: 0.0799, Valid Loss: 0.7489, Valid MER: 0.0852
# Epoch [61/200], Train Loss: 0.6396, Train MER: 0.0791, Valid Loss: 0.7296, Valid MER: 0.0844
# Epoch [62/200], Train Loss: 0.6399, Train MER: 0.0780, Valid Loss: 0.7447, Valid MER: 0.0876
# Epoch [63/200], Train Loss: 0.6350, Train MER: 0.0778, Valid Loss: 0.7337, Valid MER: 0.0831
# Epoch [64/200], Train Loss: 0.6411, Train MER: 0.0778, Valid Loss: 0.7370, Valid MER: 0.0827
# Epoch [65/200], Train Loss: 0.6397, Train MER: 0.0791, Valid Loss: 0.7249, Valid MER: 0.0871
# Epoch [66/200], Train Loss: 0.6345, Train MER: 0.0793, Valid Loss: 0.7570, Valid MER: 0.0892
# Epoch [67/200], Train Loss: 0.6328, Train MER: 0.0801, Valid Loss: 0.7405, Valid MER: 0.0859
# Epoch [68/200], Train Loss: 0.6387, Train MER: 0.0783, Valid Loss: 0.7468, Valid MER: 0.0884
# Epoch [69/200], Train Loss: 0.6321, Train MER: 0.0788, Valid Loss: 0.7444, Valid MER: 0.0830
# Epoch [70/200], Train Loss: 0.6381, Train MER: 0.0791, Valid Loss: 0.7661, Valid MER: 0.0938
# Epoch [71/200], Train Loss: 0.6417, Train MER: 0.0794, Valid Loss: 0.7257, Valid MER: 0.0851
# Epoch [72/200], Train Loss: 0.6378, Train MER: 0.0793, Valid Loss: 0.7400, Valid MER: 0.0848
# Epoch [73/200], Train Loss: 0.6280, Train MER: 0.0787, Valid Loss: 0.7564, Valid MER: 0.0910
# Epoch [74/200], Train Loss: 0.6288, Train MER: 0.0789, Valid Loss: 0.7657, Valid MER: 0.0868
# Epoch [75/200], Train Loss: 0.6365, Train MER: 0.0796, Valid Loss: 0.7338, Valid MER: 0.0891
# Epoch [76/200], Train Loss: 0.6227, Train MER: 0.0781, Valid Loss: 0.7350, Valid MER: 0.0876
# Epoch [77/200], Train Loss: 0.6292, Train MER: 0.0772, Valid Loss: 0.7504, Valid MER: 0.0856
# Epoch [78/200], Train Loss: 0.6299, Train MER: 0.0793, Valid Loss: 0.7319, Valid MER: 0.0904
# Epoch [79/200], Train Loss: 0.6301, Train MER: 0.0780, Valid Loss: 0.7114, Valid MER: 0.0802
# Epoch [80/200], Train Loss: 0.6234, Train MER: 0.0763, Valid Loss: 0.7310, Valid MER: 0.0816
# Epoch [81/200], Train Loss: 0.6191, Train MER: 0.0774, Valid Loss: 0.7330, Valid MER: 0.0856
# Epoch [82/200], Train Loss: 0.6215, Train MER: 0.0783, Valid Loss: 0.7421, Valid MER: 0.0842
# Epoch [83/200], Train Loss: 0.6231, Train MER: 0.0770, Valid Loss: 0.7333, Valid MER: 0.0875
# Epoch [84/200], Train Loss: 0.6303, Train MER: 0.0786, Valid Loss: 0.7308, Valid MER: 0.0847
# Epoch [85/200], Train Loss: 0.6214, Train MER: 0.0775, Valid Loss: 0.7693, Valid MER: 0.0961
# Epoch [86/200], Train Loss: 0.6088, Train MER: 0.0764, Valid Loss: 0.7256, Valid MER: 0.0827
# Epoch [87/200], Train Loss: 0.6155, Train MER: 0.0770, Valid Loss: 0.7374, Valid MER: 0.0873
# Epoch [88/200], Train Loss: 0.6122, Train MER: 0.0752, Valid Loss: 0.7569, Valid MER: 0.0912
# Epoch [89/200], Train Loss: 0.6158, Train MER: 0.0772, Valid Loss: 0.7210, Valid MER: 0.0862
# Epoch [90/200], Train Loss: 0.6131, Train MER: 0.0778, Valid Loss: 0.7415, Valid MER: 0.0860
# Epoch [91/200], Train Loss: 0.6182, Train MER: 0.0772, Valid Loss: 0.7369, Valid MER: 0.0837
# Epoch [92/200], Train Loss: 0.6162, Train MER: 0.0778, Valid Loss: 0.7221, Valid MER: 0.0839
# Epoch [93/200], Train Loss: 0.6098, Train MER: 0.0763, Valid Loss: 0.7270, Valid MER: 0.0839
# Epoch [94/200], Train Loss: 0.6144, Train MER: 0.0759, Valid Loss: 0.7425, Valid MER: 0.0857
# Epoch [95/200], Train Loss: 0.6165, Train MER: 0.0767, Valid Loss: 0.7501, Valid MER: 0.0921
# Epoch [96/200], Train Loss: 0.6163, Train MER: 0.0785, Valid Loss: 0.7246, Valid MER: 0.0861
# Epoch [97/200], Train Loss: 0.6144, Train MER: 0.0777, Valid Loss: 0.7432, Valid MER: 0.0868
# Epoch [98/200], Train Loss: 0.6025, Train MER: 0.0761, Valid Loss: 0.7304, Valid MER: 0.0848
# Epoch [99/200], Train Loss: 0.5951, Train MER: 0.0741, Valid Loss: 0.7166, Valid MER: 0.0849
# Epoch [100/200], Train Loss: 0.6158, Train MER: 0.0768, Valid Loss: 0.7235, Valid MER: 0.0855
# Epoch [101/200], Train Loss: 0.5784, Train MER: 0.0715, Valid Loss: 0.7102, Valid MER: 0.0828
# Epoch [102/200], Train Loss: 0.5612, Train MER: 0.0702, Valid Loss: 0.7045, Valid MER: 0.0806
# Epoch [103/200], Train Loss: 0.5618, Train MER: 0.0706, Valid Loss: 0.7197, Valid MER: 0.0841
# Epoch [104/200], Train Loss: 0.5628, Train MER: 0.0696, Valid Loss: 0.7207, Valid MER: 0.0813
# Epoch [105/200], Train Loss: 0.5567, Train MER: 0.0693, Valid Loss: 0.7142, Valid MER: 0.0831
# Epoch [106/200], Train Loss: 0.5525, Train MER: 0.0679, Valid Loss: 0.7057, Valid MER: 0.0810
# Epoch [107/200], Train Loss: 0.5543, Train MER: 0.0695, Valid Loss: 0.7148, Valid MER: 0.0829
# Epoch [108/200], Train Loss: 0.5594, Train MER: 0.0697, Valid Loss: 0.7177, Valid MER: 0.0823
# Epoch [109/200], Train Loss: 0.5497, Train MER: 0.0689, Valid Loss: 0.7159, Valid MER: 0.0802
# Epoch [110/200], Train Loss: 0.5532, Train MER: 0.0692, Valid Loss: 0.7084, Valid MER: 0.0818
# Epoch [111/200], Train Loss: 0.5506, Train MER: 0.0683, Valid Loss: 0.7080, Valid MER: 0.0808
# Epoch [112/200], Train Loss: 0.5480, Train MER: 0.0684, Valid Loss: 0.7204, Valid MER: 0.0837
# Epoch [113/200], Train Loss: 0.5494, Train MER: 0.0693, Valid Loss: 0.7241, Valid MER: 0.0842
# Epoch [114/200], Train Loss: 0.5510, Train MER: 0.0695, Valid Loss: 0.7176, Valid MER: 0.0856
# Epoch [115/200], Train Loss: 0.5472, Train MER: 0.0683, Valid Loss: 0.7137, Valid MER: 0.0817
# Epoch [116/200], Train Loss: 0.5435, Train MER: 0.0664, Valid Loss: 0.7305, Valid MER: 0.0870
# Epoch [117/200], Train Loss: 0.5487, Train MER: 0.0688, Valid Loss: 0.7258, Valid MER: 0.0827
# Epoch [118/200], Train Loss: 0.5415, Train MER: 0.0672, Valid Loss: 0.7298, Valid MER: 0.0857
# Epoch [119/200], Train Loss: 0.5459, Train MER: 0.0672, Valid Loss: 0.7231, Valid MER: 0.0825
# Epoch [120/200], Train Loss: 0.5443, Train MER: 0.0684, Valid Loss: 0.7323, Valid MER: 0.0845
# Epoch [121/200], Train Loss: 0.5441, Train MER: 0.0685, Valid Loss: 0.7163, Valid MER: 0.0827
# Epoch [122/200], Train Loss: 0.5407, Train MER: 0.0683, Valid Loss: 0.7189, Valid MER: 0.0818
# Epoch [123/200], Train Loss: 0.5497, Train MER: 0.0681, Valid Loss: 0.7108, Valid MER: 0.0835
# Epoch [124/200], Train Loss: 0.5367, Train MER: 0.0667, Valid Loss: 0.7068, Valid MER: 0.0810
# Epoch [125/200], Train Loss: 0.5427, Train MER: 0.0679, Valid Loss: 0.7069, Valid MER: 0.0832
# Epoch [126/200], Train Loss: 0.5443, Train MER: 0.0676, Valid Loss: 0.7159, Valid MER: 0.0819
# Epoch [127/200], Train Loss: 0.5416, Train MER: 0.0679, Valid Loss: 0.7180, Valid MER: 0.0826
# Epoch [128/200], Train Loss: 0.5427, Train MER: 0.0680, Valid Loss: 0.7165, Valid MER: 0.0825
# Epoch [129/200], Train Loss: 0.5352, Train MER: 0.0659, Valid Loss: 0.7133, Valid MER: 0.0841
# Epoch [130/200], Train Loss: 0.5448, Train MER: 0.0679, Valid Loss: 0.7165, Valid MER: 0.0825
# Epoch [131/200], Train Loss: 0.5385, Train MER: 0.0685, Valid Loss: 0.7167, Valid MER: 0.0817
# Epoch [132/200], Train Loss: 0.5480, Train MER: 0.0698, Valid Loss: 0.7188, Valid MER: 0.0850
# Epoch [133/200], Train Loss: 0.5431, Train MER: 0.0685, Valid Loss: 0.7329, Valid MER: 0.0841
# Epoch [134/200], Train Loss: 0.5316, Train MER: 0.0674, Valid Loss: 0.7097, Valid MER: 0.0814
# Epoch [135/200], Train Loss: 0.5355, Train MER: 0.0675, Valid Loss: 0.7216, Valid MER: 0.0832
# Epoch [136/200], Train Loss: 0.5419, Train MER: 0.0678, Valid Loss: 0.7064, Valid MER: 0.0811
# Epoch [137/200], Train Loss: 0.5376, Train MER: 0.0673, Valid Loss: 0.7058, Valid MER: 0.0829
# Epoch [138/200], Train Loss: 0.5382, Train MER: 0.0679, Valid Loss: 0.7015, Valid MER: 0.0826
# Epoch [139/200], Train Loss: 0.5276, Train MER: 0.0656, Valid Loss: 0.7015, Valid MER: 0.0813
# Epoch [140/200], Train Loss: 0.5243, Train MER: 0.0669, Valid Loss: 0.6963, Valid MER: 0.0821
# Epoch [141/200], Train Loss: 0.5382, Train MER: 0.0683, Valid Loss: 0.7029, Valid MER: 0.0796
# Epoch [142/200], Train Loss: 0.5451, Train MER: 0.0686, Valid Loss: 0.7190, Valid MER: 0.0814
# Epoch [143/200], Train Loss: 0.5347, Train MER: 0.0678, Valid Loss: 0.7127, Valid MER: 0.0808
# Epoch [144/200], Train Loss: 0.5339, Train MER: 0.0681, Valid Loss: 0.7303, Valid MER: 0.0837
# Epoch [145/200], Train Loss: 0.5385, Train MER: 0.0667, Valid Loss: 0.7021, Valid MER: 0.0818
# Epoch [146/200], Train Loss: 0.5336, Train MER: 0.0674, Valid Loss: 0.7132, Valid MER: 0.0854
# Epoch [147/200], Train Loss: 0.5339, Train MER: 0.0671, Valid Loss: 0.7299, Valid MER: 0.0890
# Epoch [148/200], Train Loss: 0.5361, Train MER: 0.0672, Valid Loss: 0.7154, Valid MER: 0.0841
# Epoch [149/200], Train Loss: 0.5319, Train MER: 0.0666, Valid Loss: 0.7275, Valid MER: 0.0856
# Epoch [150/200], Train Loss: 0.5325, Train MER: 0.0676, Valid Loss: 0.7188, Valid MER: 0.0843
# Epoch [151/200], Train Loss: 0.5056, Train MER: 0.0628, Valid Loss: 0.7064, Valid MER: 0.0811
# Epoch [152/200], Train Loss: 0.4954, Train MER: 0.0620, Valid Loss: 0.7150, Valid MER: 0.0852
# Epoch [153/200], Train Loss: 0.4963, Train MER: 0.0615, Valid Loss: 0.7073, Valid MER: 0.0809
# Epoch [154/200], Train Loss: 0.4871, Train MER: 0.0604, Valid Loss: 0.6976, Valid MER: 0.0822
# Epoch [155/200], Train Loss: 0.4893, Train MER: 0.0611, Valid Loss: 0.7034, Valid MER: 0.0819
# Epoch [156/200], Train Loss: 0.4926, Train MER: 0.0611, Valid Loss: 0.6951, Valid MER: 0.0788
# Epoch [157/200], Train Loss: 0.4891, Train MER: 0.0622, Valid Loss: 0.7111, Valid MER: 0.0818
# Epoch [158/200], Train Loss: 0.4905, Train MER: 0.0617, Valid Loss: 0.7157, Valid MER: 0.0840
# Epoch [159/200], Train Loss: 0.4947, Train MER: 0.0620, Valid Loss: 0.6953, Valid MER: 0.0798
# Epoch [160/200], Train Loss: 0.4888, Train MER: 0.0622, Valid Loss: 0.7057, Valid MER: 0.0832
# Epoch [161/200], Train Loss: 0.4899, Train MER: 0.0619, Valid Loss: 0.7114, Valid MER: 0.0807
# Epoch [162/200], Train Loss: 0.4915, Train MER: 0.0625, Valid Loss: 0.6930, Valid MER: 0.0810
# Epoch [163/200], Train Loss: 0.4869, Train MER: 0.0609, Valid Loss: 0.6999, Valid MER: 0.0813
# Epoch [164/200], Train Loss: 0.4844, Train MER: 0.0613, Valid Loss: 0.7079, Valid MER: 0.0805
# Epoch [165/200], Train Loss: 0.4889, Train MER: 0.0609, Valid Loss: 0.6937, Valid MER: 0.0804
# Epoch [166/200], Train Loss: 0.4842, Train MER: 0.0623, Valid Loss: 0.6957, Valid MER: 0.0816
# Epoch [167/200], Train Loss: 0.4883, Train MER: 0.0618, Valid Loss: 0.6915, Valid MER: 0.0794
# Epoch [168/200], Train Loss: 0.4875, Train MER: 0.0612, Valid Loss: 0.7035, Valid MER: 0.0842
# Epoch [169/200], Train Loss: 0.4849, Train MER: 0.0614, Valid Loss: 0.6967, Valid MER: 0.0794
# Epoch [170/200], Train Loss: 0.4840, Train MER: 0.0608, Valid Loss: 0.6995, Valid MER: 0.0813
# Epoch [171/200], Train Loss: 0.4853, Train MER: 0.0615, Valid Loss: 0.7003, Valid MER: 0.0807
# Epoch [172/200], Train Loss: 0.4832, Train MER: 0.0607, Valid Loss: 0.7040, Valid MER: 0.0812
# Epoch [173/200], Train Loss: 0.4837, Train MER: 0.0622, Valid Loss: 0.7087, Valid MER: 0.0784
# Epoch [174/200], Train Loss: 0.4867, Train MER: 0.0619, Valid Loss: 0.7009, Valid MER: 0.0786
# Epoch [175/200], Train Loss: 0.4867, Train MER: 0.0615, Valid Loss: 0.7092, Valid MER: 0.0820
# Epoch [176/200], Train Loss: 0.4856, Train MER: 0.0617, Valid Loss: 0.7037, Valid MER: 0.0830
# Epoch [177/200], Train Loss: 0.4793, Train MER: 0.0616, Valid Loss: 0.7052, Valid MER: 0.0821
# Epoch [178/200], Train Loss: 0.4863, Train MER: 0.0624, Valid Loss: 0.7048, Valid MER: 0.0832
# Epoch [179/200], Train Loss: 0.4882, Train MER: 0.0618, Valid Loss: 0.7050, Valid MER: 0.0839
# Epoch [180/200], Train Loss: 0.4853, Train MER: 0.0625, Valid Loss: 0.7136, Valid MER: 0.0808
# Epoch [181/200], Train Loss: 0.4825, Train MER: 0.0619, Valid Loss: 0.7052, Valid MER: 0.0833
# Epoch [182/200], Train Loss: 0.4832, Train MER: 0.0616, Valid Loss: 0.7130, Valid MER: 0.0823
# Epoch [183/200], Train Loss: 0.4783, Train MER: 0.0604, Valid Loss: 0.6992, Valid MER: 0.0792
# Epoch [184/200], Train Loss: 0.4820, Train MER: 0.0601, Valid Loss: 0.7116, Valid MER: 0.0831
# Epoch [185/200], Train Loss: 0.4799, Train MER: 0.0604, Valid Loss: 0.7096, Valid MER: 0.0828
# Epoch [186/200], Train Loss: 0.4800, Train MER: 0.0614, Valid Loss: 0.7095, Valid MER: 0.0825
# Epoch [187/200], Train Loss: 0.4763, Train MER: 0.0599, Valid Loss: 0.7093, Valid MER: 0.0858
# Epoch [188/200], Train Loss: 0.4879, Train MER: 0.0605, Valid Loss: 0.7014, Valid MER: 0.0819
# Epoch [189/200], Train Loss: 0.4739, Train MER: 0.0607, Valid Loss: 0.7086, Valid MER: 0.0820
# Epoch [190/200], Train Loss: 0.4795, Train MER: 0.0613, Valid Loss: 0.7038, Valid MER: 0.0836
# Epoch [191/200], Train Loss: 0.4774, Train MER: 0.0614, Valid Loss: 0.7040, Valid MER: 0.0831
# Epoch [192/200], Train Loss: 0.4757, Train MER: 0.0590, Valid Loss: 0.7061, Valid MER: 0.0821
# Epoch [193/200], Train Loss: 0.4837, Train MER: 0.0624, Valid Loss: 0.7018, Valid MER: 0.0803
# Epoch [194/200], Train Loss: 0.4789, Train MER: 0.0610, Valid Loss: 0.7184, Valid MER: 0.0831
# Epoch [195/200], Train Loss: 0.4733, Train MER: 0.0604, Valid Loss: 0.6995, Valid MER: 0.0830
# Epoch [196/200], Train Loss: 0.4759, Train MER: 0.0600, Valid Loss: 0.7066, Valid MER: 0.0824
# Epoch [197/200], Train Loss: 0.4787, Train MER: 0.0608, Valid Loss: 0.6976, Valid MER: 0.0848
# Epoch [198/200], Train Loss: 0.4762, Train MER: 0.0606, Valid Loss: 0.7060, Valid MER: 0.0814
# Epoch [199/200], Train Loss: 0.4759, Train MER: 0.0612, Valid Loss: 0.7061, Valid MER: 0.0834
# Epoch [200/200], Train Loss: 0.4779, Train MER: 0.0607, Valid Loss: 0.7102, Valid MER: 0.0821

# %%
print(valid_mers[-1])
# Out:
# 0.08211591

# %% [markdown]
# ---
# ## Save Model
#
# Save a `checkpoint.pth` file containing all the necessary information to retrieve your best model and predictions. Remember submitting this file to Canvas siste.
#
# Hint: Check out the `Lecture 4 - Saving and Loading Models.ipynb` on Canvas if you do not know how to save model.

# %%
print("Our model: \n\n", model, '\n')
print("The state dict keys: \n\n", model.state_dict().keys())

torch.save(model.state_dict(), 'checkpoint.pth')
# Out:
# Our model:
#
#  Sequential(
#   (0): Linear(in_features=105, out_features=512, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.15, inplace=False)
#   (3): Linear(in_features=512, out_features=256, bias=True)
#   (4): ReLU()
#   (5): Dropout(p=0.15, inplace=False)
#   (6): Linear(in_features=256, out_features=128, bias=True)
#   (7): ReLU()
#   (8): Dropout(p=0.15, inplace=False)
#   (9): Linear(in_features=128, out_features=64, bias=True)
#   (10): ReLU()
#   (11): Dropout(p=0.15, inplace=False)
#   (12): Linear(in_features=64, out_features=1, bias=True)
# )
#
# The state dict keys:
#
#  odict_keys(['0.weight', '0.bias', '3.weight', '3.bias', '6.weight', '6.bias', '9.weight', '9.bias', '12.weight', '12.bias'])

# %% [markdown]
# ---
# ## Inference on test data
#
# After the model is trained, we can use it for inference.

# %%
#TODO: write the code to generate predicted sale prices for test data
# Assuming 'model' is your trained model and 'test_loader' is your test data loader

model.eval()  # Set the model to evaluation mode
all_test_preds = []

with torch.no_grad():  # Disable gradient calculation during inference
    for test_features in test_loader:
        test_features = test_features[0].to(device)  # Get features from the batch

        # Make predictions
        outputs = model(test_features)

        # Collect predictions
        all_test_preds.extend(outputs.cpu().detach().numpy().flatten())

# Convert predictions back to original scale
predicted_sale_prices = np.array(all_test_preds) * normalization_factor
predicted_sale_prices
# Out:
# array([525828.64761353, 423822.11685181, 461836.62414551, ...,
#        327809.19075012, 547246.9329834 , 307828.85551453])

# %%
test_df = pd.read_csv("test.csv")
test_df.columns
# Out:
# Index(['ID', 'NBHD', 'PROP_CLASS', 'LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA',
#        'LAND_SQFT', 'GRD_AREA', 'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B',
#        'HLF_B', 'STORY', 'STYLE_CN', 'UNITS'],
#       dtype='object')

# %%
#TODO: save the predicted sale prices into submission_csv
import pandas as pd

# Create a DataFrame with 'Id' and 'SalePrice' columns
submission_df = pd.DataFrame({'ID': test_df['ID'], 'SALE_PRICE': predicted_sale_prices})

# Save the DataFrame to a CSV file
submission_df.to_csv('submission.csv', index=False)

# Download the CSV file (optional, if you are running this in Google Colab)
from google.colab import files
files.download('submission.csv')

# %% [markdown]
# Now, we can submit our predictions on Kaggle and see how they compare with the actual house prices (labels) on the test set.
#
# - Log in to the Kaggle website and visit the house price prediction competition page.
#
# - Click the “Submit Predictions”.
#
# - Click the “Browse Files” button in the dashed box at the bottom of the page and select the prediction file you wish to upload.
#
# - Click the “Submit” button at the bottom of the page to view your results.

# %% [markdown]
#  **Include your best test error shown on Kaggle in your case report!**

# %% [markdown]
# ---
# ## Evaluate the profit of iBuyer business model
#
#
# In class, we have dicussed the iBuyer business model and its opportunities and risks. In the following analysis, imagine you work in a consulting firm and would like to investigate the profitability of the iBuyer business model.
#
# You have taken the Mordern Analytics course and remembered that Prof. X advocated the data-driven approach in business decision making. Thus, you would like to perform analysis based on model and data.
#
# Note that since we do not know the true sale prices in the future (like test data), we need to conduct the analysis based on the historical data (train or validation data). Previously, you have already trained a multilayer perceptron model using the train data. Now, let's evaluate the profit of iBuyer business model based on the predicted prices on the **validation data**.

# %% [markdown]
# Let's first compute the predicted prices on the valid data.

# %%
## TODO: Load your best model from your saved checkpoint.pth file.
state_dict = torch.load('checkpoint.pth')
print(state_dict.keys())
model.load_state_dict(state_dict)

checkpoint = {'input_size': 105,
              'output_size': 1,
              'hidden_layers': [each.out_features for each in model.children() if hasattr(each, 'out_features')], # Check if the layer has 'out_features' attribute before accessing it
              'state_dict': model.state_dict()}

torch.save(checkpoint, 'checkpoint.pth')

def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    model = fc_model.Network(checkpoint['input_size'],
                             checkpoint['output_size'],
                             checkpoint['hidden_layers'])
    model.load_state_dict(checkpoint['state_dict'])

    return model

    model = load_checkpoint('checkpoint.pth')
print(model)
# Out:
# odict_keys(['0.weight', '0.bias', '3.weight', '3.bias', '6.weight', '6.bias', '9.weight', '9.bias', '12.weight', '12.bias'])
# Sequential(
#   (0): Linear(in_features=105, out_features=512, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.15, inplace=False)
#   (3): Linear(in_features=512, out_features=256, bias=True)
#   (4): ReLU()
#   (5): Dropout(p=0.15, inplace=False)
#   (6): Linear(in_features=256, out_features=128, bias=True)
#   (7): ReLU()
#   (8): Dropout(p=0.15, inplace=False)
#   (9): Linear(in_features=128, out_features=64, bias=True)
#   (10): ReLU()
#   (11): Dropout(p=0.15, inplace=False)
#   (12): Linear(in_features=64, out_features=1, bias=True)
# )
# <ipython-input-50-1c091736ad21>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load('checkpoint.pth')

# %%
## TODO: compute the predicted prices on valid data using your best model
model.eval()  # Set the model to evaluation mode
all_valid_preds = []

with torch.no_grad():  # Disable gradient calculation during inference
    for valid_features in valid_loader:
        valid_features = valid_features[0].to(device)  # Get features from the batch

        # Make predictions
        outputs = model(valid_features)

        # Collect predictions
        all_valid_preds.extend(outputs.cpu().detach().numpy().flatten())

# Convert predictions back to original scale
predicted_sale_prices = np.array(all_valid_preds) * normalization_factor
predicted_sale_prices
# Out:
# array([592413.75923157, 594648.64730835, 287983.27445984, ...,
#        654221.29631042, 511884.73701477, 263714.59960938])

# %% [markdown]
# Compute the signed error rates (without taking the absolute value sign), that is
#
# $$
# \text{Signed Error Rate} = \frac{\text{Predicted Price}-\text{Actual Price}}{\text{Actual Price}}
# $$
# We will call signed error rate as prediction error henceafter.

# %% [markdown]
# # **The below code will generate an error. Please run code chunks from everything until the "Build the Multi-layer Perceptron Base Model" section**

# %%
import torch
import numpy as np
valid_labels = valid_labels.cpu().numpy() * normalization_factor # Move tensor to CPU before converting to NumPy array
valid_labels = valid_labels.reshape(-1)
prediction_errors = (predicted_sale_prices - valid_labels) / valid_labels
prediction_errors
# Out:
# array([ 0.04515139,  0.00787905,  0.1293462 , ...,  0.03844647,
#        -0.13678794, -0.06117979])

# %%
valid_labels
# Out:
# array([566821.00296021, 590000.00953674, 254999.99523163, ...,
#        630000.01907349, 592999.98283386, 280900.00152588])

# %% [markdown]
# ### Analysis and visualization of valid errors

# %% [markdown]
# Let's plot the histogram of prediction errors.
#
# **Question 1**: what is the bias of the prediction errors? Include the histogram of prediction errors and the bias in your report.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calculate bias (mean of prediction errors)
bias = np.mean(prediction_errors)

# Plot histogram of prediction errors
plt.hist(prediction_errors, bins=30)
plt.title('Histogram of Prediction Errors')
plt.xlabel('Prediction Error')
plt.ylabel('Frequency')

# Add a vertical line to indicate the bias
plt.axvline(x=bias, color='r', linestyle='--', label=f'Bias: {bias:.4f}')

plt.legend()
plt.show()

print(f"Bias of prediction errors: {bias:.4f}")
# Out:
# Bias of prediction errors: 0.0186

# %% [markdown]
# ### Profit Analysis
#
# In the following profit analysis, we assume the iBuyer will make an offer to every property in the valid data based on their predicted price $PP$. We assume the iBuyer decides the offer price $OP$ according to
# $$
# OP = \frac{PP}{1+\alpha},
# $$
# where $\alpha$ is the (targted) profit margin of the iBuyer.
# Here we assume the profit margin has already taken into consideration the commission fee charged by the iBuyer
# and various costs associated such as transaction cost, administration cost, and holding cost. Note that the commission fee charged by Zillow is often around $7.5\%$ and Zillow may charge additional repair costs after home inspection. Thus we take $\alpha=12\%$ in this case study.
#
# We further assume that the iBuyer can resell the property at the same
# price as the broker in the future once the property is bought. In other words, the resell price is equal to the sale price in the valid data. This assumption may not be exactly true in practice and the iBuyer may sell the house at either a higher or lower price depending on the market trend. But our conclusion will not change too much.
#
# Based on the above two assumptions, we can now determine the percentage profit
# for a property bought by the iBuyer as
# $$
# \frac{SP- OP}{OP}.
# $$
# We use the percentage profit instead of the absolute profit because the iBuyer cannot hope to purchase all houses in the market. Therefore, the percentage profit is a better measure of the profitability of the iBuyer business model.
#  The aim of the iBuyer in this simplified setting is to purchase properties for less money than they are sold for, to generate a profit.

# %%
profit_margin = 0.12

# %% [markdown]
# **Question 2**: Consider the hypothetical scenario where the offers are all accepted regardless of their values,
# what is the average percentage profit? Do you see a big difference compared to the profit margin $\alpha$? Include your answers in the report.

# %%
OP = predicted_sale_prices / (1 + profit_margin)
SP = valid_labels
profit = (SP - OP) / OP
profit
average_profit = np.mean(profit)
average_profit
# Out:
# 0.15219479505848357

# %% [markdown]
# **Offer Acceptance Rule**
#
#
# However, not every offer will be accepted by the home owner. Given an offer price, whether the homeowner accepts it
# depends on the homeowner's perceived valuation. For the current dataset, we lack enough data to determine the homeowner's perceived valuation of the property. However, the actual sale price in the valid data serves as a reasonable proxy of the homeowner's perceived valuation. Therefore, we assume that the home owner will accept the offer, if
# $$
# OP> (1-\beta) SP,
# $$
# where $\beta$ is a discounting factor. Here the discounting factor captures the commission fee charged
# by the conventional realtors which is around 6%, as well as the convenience factor that models
# how much the homeowner values the quick transaction services of the iBuyer over the conventional
# relator. We assume $\beta = 10\%$ in this case.

# %% [markdown]
# **Question 3**: Based on the sale price in the valid data and the acceptance rule, what is the mean percentage profit among all accepted offers? Do you see a big difference compared to the targeted profit margin $\alpha$?  Include your answers in your report.

# %%
beta = 0.1
AO = OP > (1 - beta) * SP
profits = (SP[AO] - OP[AO]) / OP[AO]
average_profits = np.mean(profits)
average_profits
# Out:
# -0.02976861154917914

# %%
AO
# Out:
# array([ True, False,  True, ...,  True, False, False])

# %% [markdown]
# Let's plot the histogram of the prediction errors for those properties whose home owners accepted the offer.
#
# **Question 4**: What is the bias of the prediction errors when restricting to those properties whose owners accepted the offer? Based on the histogram and bias, can you explain your answers to Question 3?

# %%
new_prediction_errors = (predicted_sale_prices[AO] - valid_labels[AO]) / valid_labels[AO]

import matplotlib.pyplot as plt
import numpy as np
# Calculate bias (mean of prediction errors)
bias = np.mean(new_prediction_errors)

# Plot histogram of prediction errors
plt.hist(new_prediction_errors, bins=30)
plt.title('Histogram of Prediction Errors')
plt.xlabel('Prediction Error')
plt.ylabel('Frequency')

# Add a vertical line to indicate the bias
plt.axvline(x=bias, color='r', linestyle='--', label=f'Bias: {bias:.4f}')

plt.legend()
plt.show()

print(f"Bias of prediction errors: {bias:.4f}")
# Out:
# Bias of prediction errors: 0.2022
